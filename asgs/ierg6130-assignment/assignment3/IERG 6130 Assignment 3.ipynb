# %% [markdown]
# # IERG 6130 Assignment 3: Policy Gradient
#
# *2019-2020 2nd term, IERG 6130: Reinforcement Learning and Beyond. Department of Information Engineering, The Chinese University of Hong Kong. Course Instructor: Professor ZHOU Bolei. Assignment author: PENG Zhenghao.*

# %% [markdown]
# | Student Name | Student ID |
# | :----: | :----: |
# | ZHANG Yuming | 1155076738 |
#
# ------

# %% [markdown]
# Welecome to the assignment 3 of our RL course.
#
# You need to go through this self-contained notebook, which contains many TODOs in part of the cells and has special `[TODO]` signs. You need to finish all TODOs. Some of them may be easy such as uncommenting a line, some of them may be difficult such as implementing a function. You can find them by searching the `[TODO]` symbol. However, we suggest you to go through the notebook step by step, which would give you a better understanding of the content.
#
# You are encouraged to add more code on extra cells at the end of the each section to investigate the problems you think interesting. At the end of the file, we left a place for you to optionaly write comments.
#
# Please report any code bugs to us via cuhkrlcourse@googlegroups.com or via github issue. Before you submission, remember to check the submit instruction at the directory of this assignment and make sure the required contents are included in your submission.
#
# Before you get start, remember to follow the instruction at https://github.com/cuhkrlcourse/ierg6130 to setup your environment.
#
# We will cover the following knowledege in this assignment:
#
# 1. Basic policy gradient method
# 2. Policy gradient with baseline
# 3. Actor-critic framework
#
# You need to install some packages.
# 1. Install `yaml` package via `pip install pyyaml` to print training information.
# 2. Install `pandas` via `pip install pandas` to organize the learning progress.
# 3. Install `matplotlib` via `pip install matplotlib` to visualize the learning result.
# 4. Install `seaborn` via `pip install seaborn` to visualize the learning result (beautiful than matplotlib).

# %% [markdown]
# ------
#
# ## Section 1: Basic reinforcement learning pipeline
#
# (5 / 100 points)
#
# In this section, we will prepare several functions for evaulation, training RL algorithms. We will also build an `AbstractTrainer` class used as a general framework which left blanks for policy gradient methods.
#
# A essential difference of this assignment compared to the previous is that: the sampling and the optimization are splited into two phase. In each training iteration, the agent first collects a batch of samples followed by conducting the policy optimization. This modification allows us to have a clear view on the training process.

# %%
# Run this cell without modification

import time
import gym
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import seaborn as sns
import pandas as pd

from utils import *

# %%
# Run this cell without modification

def run(trainer_cls, config=None, reward_threshold=None):
    """Run the trainer and report progress, agnostic to the class of trainer
    :param trainer_cls: A trainer class 
    :param config: A dict
    :param reward_threshold: the reward threshold to break the training
    :return: The trained trainer and a dataframe containing learning progress
    """
    assert inspect.isclass(trainer_cls)
    if config is None:
        config = {}
    trainer = trainer_cls(config)
    config = trainer.config
    start = now = time.time()
    stats = []
    print("=== {} {} Training Start ===".format(trainer_cls.__name__, config["env_name"]))
    pretty_print({"Config": config})
    for i in range(config['max_iteration'] + 1):
        stat = trainer.train()
        stats.append(stat or {})
        if i % config['evaluate_interval'] == 0 or \
                i == config["max_iteration"]:
            reward = trainer.evaluate(config["evaluate_num_episodes"])
            stat["evaluate_reward"] = reward
            print("=== {} {} Iteration {} ===".format(
                trainer_cls.__name__, config["env_name"], i)
            )
            pretty_print({"Training Progress": stat})
            now = time.time()
        if reward_threshold is not None and reward > reward_threshold:
            print("In {} iteration, cupretty_printrrent mean episode reward {:.3f} is "
                  "greater than reward threshold {}. Congratulation! Now we "
                  "exit the training process.".format(
                i, reward, reward_threshold))
            break
    stats = pd.DataFrame(stats)
    return trainer, stats

# %%
# Solve the TODOs and remove `pass`

default_config = dict(
    env_name="CartPole-v0",
    
    max_iteration=1000,
    max_episode_length=1000,
    
    train_batch_size=1000,
    gamma=0.99,
    learning_rate=0.01,
    seed=0,
    
    evaluate_interval=10,
    evaluate_num_episodes=50
)


class AbstractTrainer:
    """This is the abstract class for value-based RL trainer. We will inherent
    the specify algorithm's trainer from this abstract class, so that we can
    reuse the codes.
    """

    def __init__(self, config=None):
        self.config = check_and_merge_config(config or {}, default_config)

        # Create the environment
        self.env_name = self.config['env_name']
        self.env = gym.make(self.env_name)
        if "ram" in self.env_name:  # Special process for Atari games
            self.env = wrap_deepmind_ram(self.env)

        # Apply the random seed
        self.seed = self.config["seed"]
        seed_everything(self.seed)
        self.env.seed(self.seed)

        assert isinstance(self.env.observation_space,
                          gym.spaces.Box), self.env.observation_space
        self.obs_dim = self.env.observation_space.shape[0]
        self.discrete_obs = True

        assert isinstance(self.env.action_space, gym.spaces.discrete.Discrete)
        self.act_dim = self.env.action_space.n

        self.iteration = 0
        self.start_time = time.time()
        self.iteration_time = self.start_time
        self.total_timesteps = 0
        self.total_episodes = 0

        # build the model
        self.build_model()

    def build_model(self):
        raise NotImplementedError()

    # ===== Helper functions =====
    def evaluate(self, num_episodes=10, render=False):
        """Evaluate the agents for num_episodes episodes."""
        return evaluate_agent(self, self.env, num_episodes, render)

    def to_tensor(self, array):
        """Preprocess the observation."""
        raise NotImplementedError()

    def compute_action(self, observation):
        """Return the action, which can feed to self.env.step immediately."""
        raise NotImplementedError()

    def compute_values(self, observation):
        raise NotImplementedError()

    def compute_log_probs(self, observation):
        raise NotImplementedError()

    # ===== Training-related functions =====
    def collect_samples(self):
        """Here we define the pipeline to collect sample even though
        any specify functions are not implemented yet.
        """
        iter_timesteps = 0
        iter_episodes = 0
        episode_lens = []
        episode_rewards = []
        episode_obs_list = []
        episode_act_list = []
        episode_reward_list = []
        while iter_timesteps <= self.config["train_batch_size"]:
            obs_list, act_list, reward_list = [], [], []
            obs = self.env.reset()
            steps = 0
            episode_reward = 0
            while True:
                act = self.compute_action(obs)
                next_obs, reward, done, _ = self.env.step(act)

                obs_list.append(obs)
                act_list.append(act)
                reward_list.append(reward)

                obs = next_obs.copy()
                steps += 1
                episode_reward += reward
                if done or steps > self.config["max_episode_length"]:
                    break
            iter_timesteps += steps # total number of act, obs, and reward, differ from episode
            iter_episodes += 1
            episode_rewards.append(episode_reward)
            episode_lens.append(steps)
            episode_obs_list.append(np.array(obs_list, dtype=np.float32))
            episode_act_list.append(np.array(act_list, dtype=np.float32))
            episode_reward_list.append(np.array(reward_list, dtype=np.float32))
        
        # [TODO] Uncomment everything below and understand the data structure:
        # The return `samples` is a dict that contains several fields.
        # Each field (key-value pair) contains a list.
        # Each element in list is a list represent the data in one trajectory (episode).
        # Each episode list contains the data of that field of all time steps in that episode.
        # The return `sample_info` is a dict contains logging item name and its value.
        
        samples = {
            # list of list, each index is ith episode's obs, act, reward list.
            "obs": episode_obs_list,
            "act": episode_act_list,
            "reward": episode_reward_list
        }
        
        sample_info = {
            "iter_timesteps": iter_timesteps,
            "iter_episodes": iter_episodes,
            "performance": np.mean(episode_rewards),  # help drawing figures
            "training_episode_length": {
                "mean": float(np.mean(episode_lens)),
                "max": float(np.max(episode_lens)),
                "min": float(np.min(episode_lens))
            },
            "training_episode_reward": {
                "mean": float(np.mean(episode_rewards)),
                "max": float(np.max(episode_rewards)),
                "min": float(np.min(episode_rewards))
            }
        }
        return samples, sample_info

    def process_samples(self, samples):
        raise NotImplementedError()

    def update_model(self, processed_samples):
        raise NotImplementedError()

    # ===== Training iteration =====
    def train(self):
        """Here we defined the training pipeline using the abstract
        functions."""
        info = dict(iteration=self.iteration)

        # [TODO] Uncomment the following block and go through the learning 
        # pipeline.
        
        # Collect samples
        samples, sample_info = self.collect_samples()
        info.update(sample_info)

        # Process samples
        processed_samples, processed_info = self.process_samples(samples)
        info.update(processed_info)

        # Update the model
        update_info = self.update_model(processed_samples)
        info.update(update_info)
        # each train iteration only update 1 model, but may need list of list of samples

        now = time.time()
        self.iteration += 1
        self.total_timesteps += info["iter_timesteps"]
        self.total_episodes += info["iter_episodes"]
        info["iter_time"] = now - self.iteration_time
        info["total_time"] = now - self.start_time
        info["total_episodes"] = self.total_episodes
        info["total_timesteps"] = self.total_timesteps
        self.iteration_time = now
        return info

# %%
# Run this cell without modification

class TestAbstractTrainer(AbstractTrainer):
    def build_model(self):
        pass
    def compute_action(self, _):
        return np.random.choice(self.act_dim)
test_trainer = TestAbstractTrainer()
s, s_info = test_trainer.collect_samples()
assert len(s["obs"]) == s_info["iter_episodes"]
for i in range(len(s["obs"])):
    assert s["obs"][i].shape[0] <= default_config["max_episode_length"]
    assert len(s["act"][i]) == len(s["obs"][i]) == len(s["reward"][i])
assert abs(s_info["training_episode_length"]["mean"] * s_info["iter_episodes"]
           - s_info["iter_timesteps"]) < 1
print("Test Passed!")
# Out:
# Test Passed!

# %% [markdown]
# Now we have an abstract trainer class here. We have abstracted the learning process into three phases: Collect samples, process samples and update the model. In the following sections, we will continue to fulfill the blank functions.

# %% [markdown]
# ## Section 2: Basic policy gradient method
#
# (40 / 100 points)
#
# Unlike supervised learning, in RL setting the signal: reward and the output of neural network: the action distribution parameter (like the logits in discrete case or the mean in continous case) have no direct connection in terms of gradient. That is, you can't compute the gradient from the environment to your network output.
#
# To leverage the powerful tool of gradient descent, scientists innovated a technique called policy gradient, which is computed on top of the rewards and policy network's output. Scientists prove that: the policy gradient is the gradient of expected return w.r.t. the output. So that by applying gradient descent to gradient descent algorithm you can optimize your policy network and maximize the expected return (or minimize the negative of expected return).
#
# Concretely, if we consider the expected return, the value we want to maximize, is:
#
# $$Q = \mathbb E_{\text{possible trajectories}} \sum_t r(a_t, s_t) = \sum_{s_0, a_0,..} p(s_0, a_0, ..., s_t, a_t) r(s_0, a_0, ..., s_t, a_t) = \sum_{\tau} p(\tau)r(\tau)$$
#
# wherein $\sum_t r(a_t, s_t) = r(s_0, a_0, ..., s_t, a_t) = r(\tau)$ is the trajectory return. We use $\tau$ to represent a trajectory $s_0, a_0, ..., s_t, a_t$. Note that we remove the discount factor for simplicity.
#
# Since we want to maximize Q, we can simply compute the gradient from Q to parameter $\theta$ (which is included in the action probability $p(a_t)$):
#
# $$\nabla_\theta Q = \nabla_\theta \sum_{\tau} p(\tau)r(\tau) = \sum_{\tau} r(\tau) \nabla_\theta p(\tau)$$
#
# Scientists use a famous trick to deal with the gradient of probability of trajectory: $\nabla_\theta p(\tau) = p(\tau)\cfrac{\nabla_\theta p(\tau)}{p(\tau)} = p(\tau)\nabla_\theta \log p(\tau)$.
#
# The reason for this trick is that the probability of a trajectory is the product of all related probabilities of states and actions. So introducing a log term can change the production to summation: $p_\theta(\tau) = p(s_0, a_0, ...) = p(s_0) \prod_t \pi_\theta (a_t|s_t) p(s_{t+1}|s_t, a_t)$ Now we can expand the log of product above to sum of log:
#
# $$\log p_\theta (\tau) = \log p(s_1) + \sum_t \log \pi_\theta(a_t|s_t) + \sum_t \log p(s_{t+1}|s_t, a_t)$$
#
# You will find that the first and third term are not related to the parameter of policy $\pi_\theta(\cdot)$. So when we back to $\nabla_\theta Q$, we find
#
# $$\nabla_\theta Q = \sum_{\tau} r(\tau) \nabla_\theta p(\tau) =  \sum p_\theta(\tau) ( \sum_t  \nabla_\theta \log \pi_\theta(a_t|s_t) ) r(\tau) d\tau$$
#
# The probability of trajectory is included when we sampled sufficient data from environment (Yes, so REINFORCE is a Monte Carlo algorithm) so the final form of policy gradient is:
#
# $$\nabla_\theta Q =\cfrac{1}{N}\sum_{i=1}^N [( \sum_t  \nabla_\theta \log \pi_\theta(a_{i,t}|s_{i,t}) (\sum_{t'=t} \gamma^{t'-t} r(s_{i,t'}, a_{i,t'}) )]$$
#
# This algorithm is called REINFORCE algorithm, which is a Monte Carlo Policy Gradient algorithm having long history. In this section, we will implement the it using pytorch.

# %% [markdown]
# The policy network is composed by two parts: a basic MLP serve as function approximator which predict the probabilities of actions given the observation; and a distribution layer building upon the MLP to wrap the raw logits output of neural network to a distribution and provides API for action sampling and log probability retrieving.

# %%
# Run this cell without modification

class Net(nn.Module):
    def __init__(self, obs_dim, act_dim, hidden_units=128):
        super(Net, self).__init__()
        self.fc0 = nn.Linear(obs_dim, hidden_units)
        self.fc1 = nn.Linear(hidden_units, act_dim)

    # each layer is just a function, forward is the step which go through the whole layer
    def forward(self, x):
        x = x.type_as(self.fc0.bias)
        x = F.relu(self.fc0(x))
        x = self.fc1(x)
        return x


class CategoricalPolicy(nn.Module):
    def __init__(self, obs_dim, act_dim, hidden_units=128):
        super(CategoricalPolicy, self).__init__()
        self.network = Net(obs_dim, act_dim, hidden_units)

    def forward(self, obs):
        logit = self.network(obs)
        
        # [TODO] Create an object of the class "Categorical" in torch 
        # package "distributions". Then sample an action from it.
        m = torch.distributions.Categorical(F.softmax(logit, dim=1))
        action = m.sample().cpu().detach().numpy()[0]
        
        return action

    def log_prob(self, obs, act):
        logits = self.network(obs)
        
        # [TODO] Create an object of the class "Categorical" in torch 
        # package "distributions". Then collect the log probability of
        # the action in this distribution.
        m = torch.distributions.Categorical(F.softmax(logits, dim=1))
        log_prob = m.log_prob(act)
        
        return log_prob

# Not that we do not implement GaussianPolicy here. So we can't
# apply our algorithm to the environment with continous action.

# %%
# Solve the TODOs and remove `pass`

pg_default_config = merge_config(dict(
    normalize_advantage=True,
    clip_gradient=10.0,
    hidden_units=64,
), default_config)


class PGTrainer(AbstractTrainer):
    def __init__(self, config=None):
        config = check_and_merge_config(config or {}, pg_default_config)
        super().__init__(config)

    def build_model(self):
        """Build the policy network and related optimizer"""
        # Detect whether you have GPU or not. Remember to call X.to(self.device)
        # if necessary.
        self.device = torch.device(
            "cuda" if torch.cuda.is_available() else "cpu"
        )
        
        # [TODO] Build the policy network using CategoricalPolicy
        # Hint: Remember to pass config["hidden_units"], and set policy network
        #  to the device you are using.
        self.policy = CategoricalPolicy(self.obs_dim, self.act_dim, self.config["hidden_units"])
        
        # Build the Adam optimizer.
        self.optimizer = torch.optim.Adam(
            self.policy.parameters(),
            lr=self.config["learning_rate"]
        )

    def to_tensor(self, array):
        """Transform a numpy array to a pytorch tensor"""
        return torch.from_numpy(array).to(self.device)

    def to_array(self, tensor):
        """Transform a pytorch tensor to a numpy array"""
        return tensor.cpu().detach().numpy()

    def compute_action(self, observation):
        """Compute the action for single observation"""
        assert observation.ndim == 1
        # [TODO] Sample an action from action distribution given by the policy
        # Hint: The input of policy network is a batch of data, so you need to
        #  expand the first dimension of observation before feeding it to policy network.
        action = self.policy(self.to_tensor(observation.reshape(1, self.obs_dim)))
        return action

    def compute_log_probs(self, observation, action):
        """Compute the log probabilities of a batch of state-action pair"""
        # [TODO] Using the function of policy network to get log probs.
        # Hint: Remember to transform the data into tensor before feeding it.
        log_probs = self.policy.log_prob(self.to_tensor(observation), self.to_tensor(action))
        return log_probs

    def process_samples(self, samples):
        """Process samples and add advantages in it"""
        values = []
        for reward_list in samples["reward"]:
            # reward_list contains rewards in one episode
            returns = np.zeros_like(reward_list, dtype=np.float32)
            Q = 0
            
            # [TODO] Scan the episode in a reverse order and compute the
            # discounted return at each time step. Fill the array `returns`
            # Hint: returns[n-1] = r_n-1
            #       returns[n-2] = r_n-2 + gamma * r_n-1
            #       ...
            #       returns[0] = r_0 + gamma * r_1 + gamma^2 * r_2 + ...
            #  wherein n is len(reward_list)
            pass
            for i in reversed(range(0, len(reward_list))):
                if i == len(reward_list) - 1:
                    returns[i] = reward_list[i]
                else:
                    returns[i] = reward_list[i] + self.config["gamma"] * returns[i+1]
                
            values.append(returns)

        # We call the values advantage here.
        advantages = np.concatenate(values)

        if self.config["normalize_advantage"]:
            # [TODO] normalize the advantage so that it's mean is
            # almost 0 and the its standard deviation is almost 1.
            advantages = (advantages - advantages.mean()) / max(advantages.std(), 1e-6)
        
        samples["advantages"] = advantages
        return samples, {}

    def update_model(self, processed_samples):
        """A wrapper function, call self.update_policy"""
        return self.update_policy(processed_samples)

    def update_policy(self, processed_samples):
        """Update the policy network"""
        advantages = self.to_tensor(processed_samples["advantages"])
        flat_obs = np.concatenate(processed_samples["obs"])
        flat_act = np.concatenate(processed_samples["act"])

        self.policy.train()
        self.optimizer.zero_grad()

        log_probs = self.compute_log_probs(flat_obs, flat_act)

        assert log_probs.shape == advantages.shape, "log_probs shape {} is not " \
            "compatible with advantages {}".format(log_probs.shape, advantages.shape)
        
        # [TODO] Compute the loss using log probabilities and advantages.
        loss = []
        for l, r in zip(log_probs, advantages): 
            loss.append(-l * r)
        loss = torch.stack(loss).sum()
        #print(loss)
        
        loss.backward()
        
        # Clip the gradient
        torch.nn.utils.clip_grad_norm_(
            self.policy.parameters(), self.config["clip_gradient"]
        )

        self.optimizer.step()
        self.policy.eval()
        update_info = {
            "policy_loss": loss.item(),
            "mean_log_prob": torch.mean(log_probs).item(),
            "mean_advantage": torch.mean(advantages).item()
        }
        return update_info

# %%
# Run this cell without modification

# Test advantage computing
test_trainer = PGTrainer({"normalize_advantage": False})
test_trainer.train()
fake_sample = {"reward": [[2, 2, 2, 2, 2]]}
assert_almost_equal(
    test_trainer.process_samples(fake_sample)[0]["reward"][0],
    fake_sample["reward"][0]
)
assert_almost_equal(
    test_trainer.process_samples(fake_sample)[0]["advantages"],
    np.array([9.80199, 7.880798, 5.9402, 3.98, 2.], dtype=np.float32)
)

# Test advantage normalization
test_trainer = PGTrainer(
    {"normalize_advantage": True, "env_name": "LunarLander-v2"})
test_adv = test_trainer.process_samples(fake_sample)[0]["advantages"]
assert_almost_equal(test_adv.mean(), 0.0)
assert_almost_equal(test_adv.std(), 1.0)

# Test the shape of functions' returns
fake_observation = np.array([
    test_trainer.env.observation_space.sample() for i in range(10)
])
fake_action = np.array([
    test_trainer.env.action_space.sample() for i in range(10)
])
assert test_trainer.to_tensor(fake_observation).shape == torch.Size([10, 8])
assert np.array(test_trainer.compute_action(fake_observation[0])).shape == ()
assert test_trainer.compute_log_probs(fake_observation, fake_action).shape == \
       torch.Size([10])

print("Test Passed!")
# Out:
# Test Passed!

# %%
# Run this cell without modification

pg_trainer_no_na, pg_result_no_na = run(PGTrainer, dict(
    learning_rate=0.01,
    max_episode_length=200,
    train_batch_size=200,
    normalize_advantage=False,  # <<== Here!
), 195.0)
# Out:
# === PGTrainer CartPole-v0 Training Start ===
# Config:
#   checked: true
#   clip_gradient: 10.0
#   env_name: CartPole-v0
#   evaluate_interval: 10
#   evaluate_num_episodes: 50
#   gamma: 0.99
#   hidden_units: 64
#   learning_rate: 0.01
#   max_episode_length: 200
#   max_iteration: 1000
#   normalize_advantage: false
#   seed: 0
#   train_batch_size: 200
#
# === PGTrainer CartPole-v0 Iteration 0 ===
# Training Progress:
#   evaluate_reward: 23.18
#   iter_episodes: 10
#   iter_time: 0.12035965919494629
#   iter_timesteps: 217
#   iteration: 0
#   mean_advantage: 11.939602851867676
#   mean_log_prob: -0.6919979453086853
#   performance: 21.7
#   policy_loss: 1793.7635498046875
#   total_episodes: 10
#   total_time: 0.12035965919494629
#   total_timesteps: 217
#   training_episode_length:
#     max: 32.0
#     mean: 21.7
#     min: 9.0
#   training_episode_reward:
#     max: 32.0
#     mean: 21.7
#     min: 9.0
#
# === PGTrainer CartPole-v0 Iteration 10 ===
# Training Progress:
#   evaluate_reward: 58.24
#   iter_episodes: 3
#   iter_time: 0.040678977966308594
#   iter_timesteps: 246
#   iteration: 10
#   mean_advantage: 34.35287094116211
#   mean_log_prob: -0.6174343228340149
#   performance: 82.0
#   policy_loss: 5194.1123046875
#   total_episodes: 63
#   total_time: 0.6934795379638672
#   total_timesteps: 2549
#   training_episode_length:
#     max: 123.0
#     mean: 82.0
#     min: 59.0
#   training_episode_reward:
#     max: 123.0
#     mean: 82.0
#     min: 59.0
#
# === PGTrainer CartPole-v0 Iteration 20 ===
# Training Progress:
#   evaluate_reward: 100.46
#   iter_episodes: 3
#   iter_time: 0.040886878967285156
#   iter_timesteps: 245
#   iteration: 20
#   mean_advantage: 32.579036712646484
#   mean_log_prob: -0.6084085702896118
#   performance: 81.66666666666667
#   policy_loss: 4873.6044921875
#   total_episodes: 96
#   total_time: 1.4821510314941406
#   total_timesteps: 5005
#   training_episode_length:
#     max: 94.0
#     mean: 81.66666666666667
#     min: 64.0
#   training_episode_reward:
#     max: 94.0
#     mean: 81.66666666666667
#     min: 64.0
#
# === PGTrainer CartPole-v0 Iteration 30 ===
# Training Progress:
#   evaluate_reward: 138.96
#   iter_episodes: 3
#   iter_time: 0.046701908111572266
#   iter_timesteps: 272
#   iteration: 30
#   mean_advantage: 46.58760070800781
#   mean_log_prob: -0.603961169719696
#   performance: 90.66666666666667
#   policy_loss: 7558.83447265625
#   total_episodes: 120
#   total_time: 2.6031832695007324
#   total_timesteps: 7715
#   training_episode_length:
#     max: 200.0
#     mean: 90.66666666666667
#     min: 27.0
#   training_episode_reward:
#     max: 200.0
#     mean: 90.66666666666667
#     min: 27.0
#
# === PGTrainer CartPole-v0 Iteration 40 ===
# Training Progress:
#   evaluate_reward: 175.12
#   iter_episodes: 2
#   iter_time: 0.06058168411254883
#   iter_timesteps: 371
#   iteration: 40
#   mean_advantage: 54.990882873535156
#   mean_log_prob: -0.5928560495376587
#   performance: 185.5
#   policy_loss: 12080.8740234375
#   total_episodes: 140
#   total_time: 4.058980941772461
#   total_timesteps: 10924
#   training_episode_length:
#     max: 200.0
#     mean: 185.5
#     min: 171.0
#   training_episode_reward:
#     max: 200.0
#     mean: 185.5
#     min: 171.0
#
# === PGTrainer CartPole-v0 Iteration 50 ===
# Training Progress:
#   evaluate_reward: 161.72
#   iter_episodes: 2
#   iter_time: 0.0663766860961914
#   iter_timesteps: 396
#   iteration: 50
#   mean_advantage: 56.83637237548828
#   mean_log_prob: -0.5828325152397156
#   performance: 198.0
#   policy_loss: 13075.9443359375
#   total_episodes: 161
#   total_time: 5.746711015701294
#   total_timesteps: 14241
#   training_episode_length:
#     max: 200.0
#     mean: 198.0
#     min: 196.0
#   training_episode_reward:
#     max: 200.0
#     mean: 198.0
#     min: 196.0
#
# === PGTrainer CartPole-v0 Iteration 60 ===
# Training Progress:
#   evaluate_reward: 173.6
#   iter_episodes: 2
#   iter_time: 0.07372140884399414
#   iter_timesteps: 400
#   iteration: 60
#   mean_advantage: 57.131980895996094
#   mean_log_prob: -0.5676714181900024
#   performance: 200.0
#   policy_loss: 13028.99609375
#   total_episodes: 182
#   total_time: 7.480183124542236
#   total_timesteps: 17720
#   training_episode_length:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#   training_episode_reward:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#
# === PGTrainer CartPole-v0 Iteration 70 ===
# Training Progress:
#   evaluate_reward: 195.84
#   iter_episodes: 2
#   iter_time: 0.06563830375671387
#   iter_timesteps: 400
#   iteration: 70
#   mean_advantage: 57.131980895996094
#   mean_log_prob: -0.5589467883110046
#   performance: 200.0
#   policy_loss: 12739.4833984375
#   total_episodes: 202
#   total_time: 9.222798347473145
#   total_timesteps: 21213
#   training_episode_length:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#   training_episode_reward:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#
# In 70 iteration, cupretty_printrrent mean episode reward 195.840 is greater than reward threshold 195.0. Congratulation! Now we exit the training process.

# %%
# Run this cell without modification

pg_trainer_na, pg_result_na = run(PGTrainer, dict(
    learning_rate=0.01,
    max_episode_length=200,
    train_batch_size=200,
    normalize_advantage=True,  # <<== Here!
), 195.0)
# Out:
# === PGTrainer CartPole-v0 Training Start ===
# Config:
#   checked: true
#   clip_gradient: 10.0
#   env_name: CartPole-v0
#   evaluate_interval: 10
#   evaluate_num_episodes: 50
#   gamma: 0.99
#   hidden_units: 64
#   learning_rate: 0.01
#   max_episode_length: 200
#   max_iteration: 1000
#   normalize_advantage: true
#   seed: 0
#   train_batch_size: 200
#
# === PGTrainer CartPole-v0 Iteration 0 ===
# Training Progress:
#   evaluate_reward: 27.24
#   iter_episodes: 10
#   iter_time: 0.040390729904174805
#   iter_timesteps: 217
#   iteration: 0
#   mean_advantage: -3.7355906812308604e-08
#   mean_log_prob: -0.6919979453086853
#   performance: 21.7
#   policy_loss: 0.11937189102172852
#   total_episodes: 10
#   total_time: 0.040390729904174805
#   total_timesteps: 217
#   training_episode_length:
#     max: 32.0
#     mean: 21.7
#     min: 9.0
#   training_episode_reward:
#     max: 32.0
#     mean: 21.7
#     min: 9.0
#
# === PGTrainer CartPole-v0 Iteration 10 ===
# Training Progress:
#   evaluate_reward: 67.16
#   iter_episodes: 2
#   iter_time: 0.041155099868774414
#   iter_timesteps: 248
#   iteration: 10
#   mean_advantage: -7.017965941713555e-08
#   mean_log_prob: -0.6186385750770569
#   performance: 124.0
#   policy_loss: -0.6668108105659485
#   total_episodes: 67
#   total_time: 0.620100736618042
#   total_timesteps: 2526
#   training_episode_length:
#     max: 169.0
#     mean: 124.0
#     min: 79.0
#   training_episode_reward:
#     max: 169.0
#     mean: 124.0
#     min: 79.0
#
# === PGTrainer CartPole-v0 Iteration 20 ===
# Training Progress:
#   evaluate_reward: 123.32
#   iter_episodes: 3
#   iter_time: 0.041228532791137695
#   iter_timesteps: 244
#   iteration: 20
#   mean_advantage: -5.6184706664907935e-08
#   mean_log_prob: -0.6076608300209045
#   performance: 81.33333333333333
#   policy_loss: 2.9918112754821777
#   total_episodes: 100
#   total_time: 1.5115082263946533
#   total_timesteps: 5084
#   training_episode_length:
#     max: 115.0
#     mean: 81.33333333333333
#     min: 64.0
#   training_episode_reward:
#     max: 115.0
#     mean: 81.33333333333333
#     min: 64.0
#
# === PGTrainer CartPole-v0 Iteration 30 ===
# Training Progress:
#   evaluate_reward: 176.64
#   iter_episodes: 2
#   iter_time: 0.06312751770019531
#   iter_timesteps: 385
#   iteration: 30
#   mean_advantage: -1.3004649801473533e-08
#   mean_log_prob: -0.5720319747924805
#   performance: 192.5
#   policy_loss: -8.292303085327148
#   total_episodes: 123
#   total_time: 2.8077290058135986
#   total_timesteps: 7925
#   training_episode_length:
#     max: 200.0
#     mean: 192.5
#     min: 185.0
#   training_episode_reward:
#     max: 200.0
#     mean: 192.5
#     min: 185.0
#
# === PGTrainer CartPole-v0 Iteration 40 ===
# Training Progress:
#   evaluate_reward: 194.28
#   iter_episodes: 2
#   iter_time: 0.06331539154052734
#   iter_timesteps: 386
#   iteration: 40
#   mean_advantage: -4.2618864881660556e-08
#   mean_log_prob: -0.5526455044746399
#   performance: 193.0
#   policy_loss: -3.0792551040649414
#   total_episodes: 143
#   total_time: 4.5686047077178955
#   total_timesteps: 11716
#   training_episode_length:
#     max: 200.0
#     mean: 193.0
#     min: 186.0
#   training_episode_reward:
#     max: 200.0
#     mean: 193.0
#     min: 186.0
#
# === PGTrainer CartPole-v0 Iteration 50 ===
# Training Progress:
#   evaluate_reward: 194.46
#   iter_episodes: 2
#   iter_time: 0.06548094749450684
#   iter_timesteps: 400
#   iteration: 50
#   mean_advantage: -1.3530254250326834e-07
#   mean_log_prob: -0.5184391140937805
#   performance: 200.0
#   policy_loss: -0.687911868095398
#   total_episodes: 163
#   total_time: 6.455714225769043
#   total_timesteps: 15541
#   training_episode_length:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#   training_episode_reward:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#
# === PGTrainer CartPole-v0 Iteration 60 ===
# Training Progress:
#   evaluate_reward: 179.9
#   iter_episodes: 2
#   iter_time: 0.053998708724975586
#   iter_timesteps: 328
#   iteration: 60
#   mean_advantage: -2.253346309544213e-08
#   mean_log_prob: -0.5553460717201233
#   performance: 164.0
#   policy_loss: 6.210851192474365
#   total_episodes: 183
#   total_time: 8.351449489593506
#   total_timesteps: 19422
#   training_episode_length:
#     max: 177.0
#     mean: 164.0
#     min: 151.0
#   training_episode_reward:
#     max: 177.0
#     mean: 164.0
#     min: 151.0
#
# === PGTrainer CartPole-v0 Iteration 70 ===
# Training Progress:
#   evaluate_reward: 167.02
#   iter_episodes: 2
#   iter_time: 0.05388069152832031
#   iter_timesteps: 328
#   iteration: 70
#   mean_advantage: 1.4174275975165074e-07
#   mean_log_prob: -0.5337023138999939
#   performance: 164.0
#   policy_loss: -9.32563304901123
#   total_episodes: 203
#   total_time: 10.085375785827637
#   total_timesteps: 22904
#   training_episode_length:
#     max: 181.0
#     mean: 164.0
#     min: 147.0
#   training_episode_reward:
#     max: 181.0
#     mean: 164.0
#     min: 147.0
#
# === PGTrainer CartPole-v0 Iteration 80 ===
# Training Progress:
#   evaluate_reward: 164.82
#   iter_episodes: 2
#   iter_time: 0.052321434020996094
#   iter_timesteps: 318
#   iteration: 80
#   mean_advantage: 3.7487200010843935e-09
#   mean_log_prob: -0.525253415107727
#   performance: 159.0
#   policy_loss: -8.100683212280273
#   total_episodes: 223
#   total_time: 11.688958168029785
#   total_timesteps: 26047
#   training_episode_length:
#     max: 182.0
#     mean: 159.0
#     min: 136.0
#   training_episode_reward:
#     max: 182.0
#     mean: 159.0
#     min: 136.0
#
# === PGTrainer CartPole-v0 Iteration 90 ===
# Training Progress:
#   evaluate_reward: 173.44
#   iter_episodes: 2
#   iter_time: 0.05521082878112793
#   iter_timesteps: 337
#   iteration: 90
#   mean_advantage: 9.83388233066762e-08
#   mean_log_prob: -0.48304933309555054
#   performance: 168.5
#   policy_loss: -4.793988227844238
#   total_episodes: 243
#   total_time: 13.340148687362671
#   total_timesteps: 29588
#   training_episode_length:
#     max: 171.0
#     mean: 168.5
#     min: 166.0
#   training_episode_reward:
#     max: 171.0
#     mean: 168.5
#     min: 166.0
#
# === PGTrainer CartPole-v0 Iteration 100 ===
# Training Progress:
#   evaluate_reward: 138.62
#   iter_episodes: 2
#   iter_time: 0.052819013595581055
#   iter_timesteps: 319
#   iteration: 100
#   mean_advantage: 2.0179628634764413e-08
#   mean_log_prob: -0.49678900837898254
#   performance: 159.5
#   policy_loss: 1.616474986076355
#   total_episodes: 263
#   total_time: 15.039782047271729
#   total_timesteps: 33114
#   training_episode_length:
#     max: 179.0
#     mean: 159.5
#     min: 140.0
#   training_episode_reward:
#     max: 179.0
#     mean: 159.5
#     min: 140.0
#
# === PGTrainer CartPole-v0 Iteration 110 ===
# Training Progress:
#   evaluate_reward: 75.84
#   iter_episodes: 4
#   iter_time: 0.04262971878051758
#   iter_timesteps: 257
#   iteration: 110
#   mean_advantage: 4.8240334393767625e-08
#   mean_log_prob: -0.4474996328353882
#   performance: 64.25
#   policy_loss: 5.561135768890381
#   total_episodes: 286
#   total_time: 16.35714840888977
#   total_timesteps: 35645
#   training_episode_length:
#     max: 83.0
#     mean: 64.25
#     min: 40.0
#   training_episode_reward:
#     max: 83.0
#     mean: 64.25
#     min: 40.0
#
# === PGTrainer CartPole-v0 Iteration 120 ===
# Training Progress:
#   evaluate_reward: 112.68
#   iter_episodes: 2
#   iter_time: 0.040474891662597656
#   iter_timesteps: 226
#   iteration: 120
#   mean_advantage: 5.802221991757506e-08
#   mean_log_prob: -0.46897268295288086
#   performance: 113.0
#   policy_loss: 6.828710556030273
#   total_episodes: 313
#   total_time: 17.238916397094727
#   total_timesteps: 37963
#   training_episode_length:
#     max: 124.0
#     mean: 113.0
#     min: 102.0
#   training_episode_reward:
#     max: 124.0
#     mean: 113.0
#     min: 102.0
#
# === PGTrainer CartPole-v0 Iteration 130 ===
# Training Progress:
#   evaluate_reward: 192.44
#   iter_episodes: 2
#   iter_time: 0.062072038650512695
#   iter_timesteps: 379
#   iteration: 130
#   mean_advantage: 1.5097747052550403e-08
#   mean_log_prob: -0.4230784773826599
#   performance: 189.5
#   policy_loss: -3.437671184539795
#   total_episodes: 333
#   total_time: 18.45294761657715
#   total_timesteps: 40889
#   training_episode_length:
#     max: 200.0
#     mean: 189.5
#     min: 179.0
#   training_episode_reward:
#     max: 200.0
#     mean: 189.5
#     min: 179.0
#
# === PGTrainer CartPole-v0 Iteration 140 ===
# Training Progress:
#   evaluate_reward: 195.74
#   iter_episodes: 2
#   iter_time: 0.06403326988220215
#   iter_timesteps: 392
#   iteration: 140
#   mean_advantage: -1.6239224009950703e-07
#   mean_log_prob: -0.41904398798942566
#   performance: 196.0
#   policy_loss: -3.770535945892334
#   total_episodes: 353
#   total_time: 20.334850311279297
#   total_timesteps: 44795
#   training_episode_length:
#     max: 199.0
#     mean: 196.0
#     min: 193.0
#   training_episode_reward:
#     max: 199.0
#     mean: 196.0
#     min: 193.0
#
# In 140 iteration, cupretty_printrrent mean episode reward 195.740 is greater than reward threshold 195.0. Congratulation! Now we exit the training process.

# %%
# Run this cell without modification

pg_result_no_na["normalize_advantage"] = False
pg_result_na["normalize_advantage"] = True
pg_result = pd.concat([pg_result_no_na, pg_result_na])
ax = sns.lineplot(
    x="total_timesteps", 
    y="performance", 
    data=pg_result, hue="normalize_advantage",
)
ax.set_title("Policy Gradient")
# Out:
# Text(0.5, 1.0, 'Policy Gradient')

# %% [markdown]
# ## Section 3: Policy gradient with baseline
#
# (25 / 100 points)
#
# Recall the REINFORCE algorithm above. We compute the gradient of $Q = \mathop{\mathbb E} \sum_t r(a_t, s_t)$ w.r.t. the parameter to update the policy. A natural question is that, when you take an inferior action that lead to positive expected return, the policy gradient is also positive and you will update your network toward this action. At the same time a potential better action is ignored.
#
# To tackle this problem, we introduce "baseline" when computing the policy gradient. The insight behind this is that we want to optimize the policy toward an action that are better than the average performance when taking all action into consideration at a given state.
#
# We introduce $b_{t} = \mathbb E_{a_t} \sum_{t'}{\gamma^{t'-t} r(s_{t'}, a_{t'})}$ as the baseline. It average all possible actions at state $s_t$. So that the profit achieved by action $a_t$ can be evaluated via $\sum_{t'=t} \gamma^{t' -t}r(a_{t'}, s_{t'}) - b_t$
#
# Therefore, the policy gradient becomes:
#
# $$\nabla_\theta Q =\cfrac{1}{N}\sum_{i=1}^N [( \sum_t  \nabla_\theta \log \pi_\theta(a_{i,t}|s_{i,t}) (\sum_{t'} \gamma^{t'-t} r(s_{i,{t’}}, a_{i,t‘}) - b_{i, t})]$$
#
# In our implementation, we estimate the baseline via an extra network `self.baseline`, which has same structure of policy network but output only a scalar value. We use the output of this network to serve as the baseline, while this network is updated by fitting the true value of expected return of current state: $\mathbb E_{a_t} \sum_{t'}{\gamma^{t'-t} r(s_{t'}, a_{t'})}$
#
# In implementation, we use a trick to match the distribution of baseline and values. During training, we first collect a batch of target values: $\{t_i= \mathbb E_{a_t} \sum_{t'}{\gamma^{t'-t} r(s_{t'}, a_{t'})}\}_i$. Then we normalzie all targets to standard distribution with mean = 0 and std = 1. Then we ask the baseline network to fit such normalized targets.
#
# When computing the advantages, instead of using the output of baseline network as the baseline $b$, we firstly match the baseline distribution with action values. The transformed baselines $b' = f(b)$ should has the same means of action values and same STD of action values too. Then we compute the advantage of current action: $adv_{i,t} = \sum_{t'} \gamma^{t'-t} r(s_{i,{t'}}, a_{i,t'}) - b'_{i, t}$
#
# By doing this, we mitigate the instability of training baseline.
#
# Hint: We suggest to normalize an array via: `(x - x.mean()) / max(x.std(), 1e-6)`. The max term can avoid potential risk of error.

# %%
pg_with_baseline_default_config = merge_config(dict(), pg_default_config)

class PolicyGradientWithBaselineTrainer(PGTrainer):
    def __init__(self, config=None):
        config = check_and_merge_config(config or {}, pg_with_baseline_default_config)
        super().__init__(config)

    def build_model(self):
        # Build the actor in name of self.policy
        super().build_model()
        
        # [TODO] Build the baseline network using Net class.
        # Remember that you need to set the output dimension to 1.
        # Remember using model.to(device) function to move your model to GPU (if applicable)
        self.baseline = Net(self.obs_dim, 1, self.config["hidden_units"])
        
        self.baseline_loss = nn.MSELoss()
            
        self.baseline_optimizer = torch.optim.Adam(
            self.baseline.parameters(),
            lr=self.config["learning_rate"]
        )

    def process_samples(self, samples):
        # Call the original process_samples function to get advantages
        tmp_samples, _ = super().process_samples(samples)
        values = tmp_samples["advantages"]
        samples["values"] = values  # We add q_values into samples

        # [TODO] flatten the observations in all trajectories (still a numpy array)
        obs = None
        for obs_array in samples["obs"]:
            if obs is None: 
                obs = obs_array 
            else: 
                obs = np.vstack((obs, obs_array)) 
        
        assert obs.ndim == 2
        assert obs.shape[1] == self.obs_dim
        
        obs = self.to_tensor(obs)
        samples["flat_obs"] = obs

        # [TODO] Compute the baseline by feeding observation to baseline network
        # Hint: baselines turns out to be a numpy array with the same shape of `values`,
        #  that is: (batch size, )
        logit = self.baseline(obs)
        m = torch.distributions.Categorical(F.softmax(logit, dim=1))
        baselines = self.to_array(m.sample())
        
        assert baselines.shape == values.shape
        
        # [TODO] Match the distribution of baselines to the values.
        # Hint: We expect to see baselines.std almost equals to values.std, 
        #  and baselines.mean almost equals to values.mean
        baselines = (baselines - baselines.mean()) / max(baselines.std(), 1e-6)
        values = (values - values.mean()) / max(values.std(), 1e-6)

        # Compute the advantage
        advantages = values - baselines
        samples["advantages"] = advantages
        process_info = {"mean_baseline": float(np.mean(baselines))}
        return samples, process_info

    def update_model(self, processed_samples):
        update_info = {}
        update_info.update(self.update_baseline(processed_samples))
        update_info.update(self.update_policy(processed_samples))
        return update_info

    def update_baseline(self, processed_samples):
        self.baseline.train()
        obs = processed_samples["flat_obs"]

        # [TODO] Normalize the values to mean=0, std=1.
        values = processed_samples["values"]
        values = (values - values.mean()) / max(values.std(), 1e-6)
        
        values = self.to_tensor(values[:, np.newaxis])
        
        baselines = self.baseline(obs)

        self.baseline_optimizer.zero_grad()
        loss = self.baseline_loss(input=baselines, target=values)
        loss.backward()
        
        # Clip the gradient
        torch.nn.utils.clip_grad_norm_(
            self.baseline.parameters(), self.config["clip_gradient"]
        )
        
        self.baseline_optimizer.step()
        self.baseline.eval()
        return dict(baseline_loss=loss.item())

# %%
# Run this cell without modification

pg_trainer_wb, pgwb_result_wb = run(PolicyGradientWithBaselineTrainer, dict(
    learning_rate=0.01,
    max_episode_length=200,
    train_batch_size=200,
), 195.0)
# Out:
# === PolicyGradientWithBaselineTrainer CartPole-v0 Training Start ===
# Config:
#   checked: true
#   clip_gradient: 10.0
#   env_name: CartPole-v0
#   evaluate_interval: 10
#   evaluate_num_episodes: 50
#   gamma: 0.99
#   hidden_units: 64
#   learning_rate: 0.01
#   max_episode_length: 200
#   max_iteration: 1000
#   normalize_advantage: true
#   seed: 0
#   train_batch_size: 200
#
# === PolicyGradientWithBaselineTrainer CartPole-v0 Iteration 0 ===
# Training Progress:
#   baseline_loss: 1.075186848640442
#   evaluate_reward: 24.68
#   iter_episodes: 11
#   iter_time: 0.04089522361755371
#   iter_timesteps: 209
#   iteration: 0
#   mean_advantage: 1.3564334531720175e-08
#   mean_baseline: 0.0
#   mean_log_prob: -0.6912497878074646
#   performance: 19.0
#   policy_loss: 0.24247664164229432
#   total_episodes: 11
#   total_time: 0.04089522361755371
#   total_timesteps: 209
#   training_episode_length:
#     max: 40.0
#     mean: 19.0
#     min: 12.0
#   training_episode_reward:
#     max: 40.0
#     mean: 19.0
#     min: 12.0
#
# === PolicyGradientWithBaselineTrainer CartPole-v0 Iteration 10 ===
# Training Progress:
#   baseline_loss: 0.9253748655319214
#   evaluate_reward: 59.28
#   iter_episodes: 5
#   iter_time: 0.040462493896484375
#   iter_timesteps: 224
#   iteration: 10
#   mean_advantage: 5.022489598819188e-09
#   mean_baseline: 0.0
#   mean_log_prob: -0.6312651038169861
#   performance: 44.8
#   policy_loss: -6.3220886200909865
#   total_episodes: 74
#   total_time: 0.6124322414398193
#   total_timesteps: 2433
#   training_episode_length:
#     max: 89.0
#     mean: 44.8
#     min: 13.0
#   training_episode_reward:
#     max: 89.0
#     mean: 44.8
#     min: 13.0
#
# === PolicyGradientWithBaselineTrainer CartPole-v0 Iteration 20 ===
# Training Progress:
#   baseline_loss: 0.9128680229187012
#   evaluate_reward: 102.58
#   iter_episodes: 2
#   iter_time: 0.03892374038696289
#   iter_timesteps: 219
#   iteration: 20
#   mean_advantage: 6.315132526502217e-09
#   mean_baseline: 0.0
#   mean_log_prob: -0.5594896078109741
#   performance: 109.5
#   policy_loss: -7.406525243518861
#   total_episodes: 112
#   total_time: 1.4289097785949707
#   total_timesteps: 4819
#   training_episode_length:
#     max: 129.0
#     mean: 109.5
#     min: 90.0
#   training_episode_reward:
#     max: 129.0
#     mean: 109.5
#     min: 90.0
#
# === PolicyGradientWithBaselineTrainer CartPole-v0 Iteration 30 ===
# Training Progress:
#   baseline_loss: 0.5155946016311646
#   evaluate_reward: 173.36
#   iter_episodes: 2
#   iter_time: 0.06358528137207031
#   iter_timesteps: 315
#   iteration: 30
#   mean_advantage: -2.0805450658949594e-08
#   mean_baseline: 0.0
#   mean_log_prob: -0.5631356835365295
#   performance: 157.5
#   policy_loss: -5.265375976806186
#   total_episodes: 136
#   total_time: 2.6002111434936523
#   total_timesteps: 7522
#   training_episode_length:
#     max: 199.0
#     mean: 157.5
#     min: 116.0
#   training_episode_reward:
#     max: 199.0
#     mean: 157.5
#     min: 116.0
#
# === PolicyGradientWithBaselineTrainer CartPole-v0 Iteration 40 ===
# Training Progress:
#   baseline_loss: 1.0581402778625488
#   evaluate_reward: 186.84
#   iter_episodes: 2
#   iter_time: 0.05898737907409668
#   iter_timesteps: 292
#   iteration: 40
#   mean_advantage: 1.6763806343078613e-08
#   mean_baseline: 0.0
#   mean_log_prob: -0.5776292085647583
#   performance: 146.0
#   policy_loss: -6.138041507126671
#   total_episodes: 156
#   total_time: 4.425375938415527
#   total_timesteps: 11112
#   training_episode_length:
#     max: 200.0
#     mean: 146.0
#     min: 92.0
#   training_episode_reward:
#     max: 200.0
#     mean: 146.0
#     min: 92.0
#
# === PolicyGradientWithBaselineTrainer CartPole-v0 Iteration 50 ===
# Training Progress:
#   baseline_loss: 0.8577479720115662
#   evaluate_reward: 190.98
#   iter_episodes: 2
#   iter_time: 0.08129262924194336
#   iter_timesteps: 400
#   iteration: 50
#   mean_advantage: -1.9173603504896163e-08
#   mean_baseline: 0.0
#   mean_log_prob: -0.5798038244247437
#   performance: 200.0
#   policy_loss: 0.8749938857298858
#   total_episodes: 176
#   total_time: 6.370957136154175
#   total_timesteps: 14872
#   training_episode_length:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#   training_episode_reward:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#
# === PolicyGradientWithBaselineTrainer CartPole-v0 Iteration 60 ===
# Training Progress:
#   baseline_loss: 0.8124680519104004
#   evaluate_reward: 185.34
#   iter_episodes: 2
#   iter_time: 0.08333110809326172
#   iter_timesteps: 400
#   iteration: 60
#   mean_advantage: -1.9173603504896163e-08
#   mean_baseline: 0.0
#   mean_log_prob: -0.5738285183906555
#   performance: 200.0
#   policy_loss: -16.350388578167028
#   total_episodes: 196
#   total_time: 8.42349648475647
#   total_timesteps: 18872
#   training_episode_length:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#   training_episode_reward:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#
# === PolicyGradientWithBaselineTrainer CartPole-v0 Iteration 70 ===
# Training Progress:
#   baseline_loss: 0.6073960661888123
#   evaluate_reward: 196.34
#   iter_episodes: 2
#   iter_time: 0.09055829048156738
#   iter_timesteps: 400
#   iteration: 70
#   mean_advantage: -1.9173603504896163e-08
#   mean_baseline: 0.0
#   mean_log_prob: -0.5543672442436218
#   performance: 200.0
#   policy_loss: -13.288325270127103
#   total_episodes: 216
#   total_time: 10.424315690994263
#   total_timesteps: 22776
#   training_episode_length:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#   training_episode_reward:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#
# In 70 iteration, cupretty_printrrent mean episode reward 196.340 is greater than reward threshold 195.0. Congratulation! Now we exit the training process.

# %%
# Run this cell without modification

pg_result_no_na["normalize_advantage"] = False
pg_result_na["normalize_advantage"] = True
pgwb_result_wb["normalize_advantage"] = "True with Baseline"
pg_result = pd.concat([pg_result_no_na, pg_result_na, pgwb_result_wb])
ax = sns.lineplot(
    x="total_timesteps", 
    y="performance", 
    data=pg_result, hue="normalize_advantage",
)
ax.set_title("Policy Gradient")
# Out:
# /home/shi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# Text(0.5, 1.0, 'Policy Gradient')

# %%
# Run this cell without modification

# You should see a pop up window which display the movement of the cart and pole.
print("Average episode reward for your Policy Gradient agent in CartPole-v0: ",
      pg_trainer_wb.evaluate(1, render=True))
# Out:
# Average episode reward for your Policy Gradient agent in CartPole-v0:  200.0

# %% [markdown]
# ## Section 4: Actor-critic Method
#
# (30 / 100 points totally)
#
# ### Section 4.1: Implement ActorCriticTrainer
#
# (20 / 100 points)

# %% [markdown]
# As point out in the textbook Page 331, the difference of Actor-critic methods and policy gradient with baseline method is whether the critic (baseline) participates in the bootstrapping. In `PolicyGradientWithBaselineTrainer`, we update the baseline network by fitting the ground-truth Q values. However, in actor-critic trainer presented below, we update the critic via fitting a bootstrapped target:
#
# $$\delta = r_t + \gamma V(s_{t+1}) - V(s_t)$$
#
# wherein $V$ is the values predicted by critic. In `ActorCriticTrainer`, in order to reuse the codes, we use `self.baseline` to represent the critic network.

# %%
# Solve the TODOs and remove `pass`

ac_default_config = merge_config(dict(
    normalize_advantage=True,
    num_critic_updates=10,
    num_critic_update_steps=10
), pg_with_baseline_default_config)

class ActorCriticTrainer(PolicyGradientWithBaselineTrainer):
    def __init__(self, config=None):
        config = check_and_merge_config(config or {}, ac_default_config)
        super().__init__(config)
        
    def process_samples(self, samples):
        """
        In this function, we will compute the target of value function
        and also the advantage used for updating policy.
        
        First, we need to prepare data to compute the values.
        
        Consider you only collect two trajectories in samples.
        Then the data structure should be:
            samples["obs"] = [
                [
                    obs_t1_0,  <<= t=0
                    obs_t1_1,  <<= t=1
                    obs_t1_n1-1, <<= t=n1-1 
                ],  (the traj t1 has length = n1)
                [
                    obs_t2_0,
                    ...
                    obs_t2_n2-1 
                ]   (the traj t2 has length = n2)
            ]
        the whole training batch size is N = (n1 + n2).
        Then what you should do is to take store
        [
            obs_t1_1, ..., obs_t1_n1-1, ZERO, 
            obs_t2_1, ... obs_t2_n2-1, ZERO
        ]
        into `next_obs` variable, wherein ZERO is a zero array has
        same shape as any other observation.
        
        Besides, you also need to prepare a boolean array `masks`
        who has length N. It should be like:
        [
            False(0), ..., False(n1-2), True(n1-1),
            False(0), ..., False(n2-2), True(n2-1)
        ].
        It represents whether a transition is terminal transition
        and whether a observation in next_obs should be masked.
        We will used it when computing the bootstrapped values:
        
            value_t = reward_t + gamma * value_t+1 * (1 - masks)
            
        So that we will not consider the impact of value_t+1
        in terminal state.
        
        Then, we need to compute the values and advantage based on 
        the data collected and form a processed_samples for the 
        consecetive .
        """
        # Define the sum of all trajectory length as N (train batch size)
        N = sum([len(traj) for traj in samples["obs"]])
        n = len(samples["obs"][0])  # the first traj length
        
        #print("N = " + str(N) + ", n = " + str(n))
        
        # [TODO] Create an array named next_obs.
        # In each trajectory, take the observations from second
        # transitions to the end. Fill an extra all zero observation
        # at the end of trajectory to align next_obs with others.
        next_obs = []
        zero = np.zeros(self.obs_dim)
        
        for obs_list in samples["obs"]:
            for i in range(len(obs_list)):
                if i + 1 == len(obs_list):
                    next_obs.append(zero)
                else:
                    next_obs.append(obs_list[i + 1])
            
        next_obs = np.array(next_obs)
        
        assert next_obs.shape == (N, self.obs_dim)
        assert np.all(next_obs[n - 1] == 0.0)
        
        # [TODO] Scan all trajectories and create a boolean array `masks`.
        # It should be N length, N is the sum of the trajectories lengths.
        # You should loop over each trajectory and store n-1 False into masks
        # while storing one True at the end of each episode. n is the length
        # of current trajectory.
        # Finally, you should transform the list to an float32 array
        # with shape (N,)
        masks = []
        for obs_list in samples["obs"]:
            for i in range(len(obs_list)):
                if i + 1 == len(obs_list):
                    masks.append(True)
                else:
                    masks.append(False)
            
        masks = np.array(masks, dtype=np.float32)
        
        assert masks.shape == (N,)
        assert masks[n - 1] == True
        
        # flatten rewards
        rewards = np.concatenate(samples["reward"])
        tensor_rewards = self.to_tensor(rewards)
        
        # flatten observations
        obs = np.concatenate(samples["obs"])
        
        # [TODO] Compute the bootstrapped values
        # Hint: value_t = reward_t + gamma * value_t+1 * (1 - masks)
        #  You need to ask self.baseline using next_obs to get 
        #  the values in next state, then can you compute the 
        #  value_t.
        tensor_next_obs = self.to_tensor(next_obs)
        value_t_p1 = self.baseline(tensor_next_obs).squeeze()
        ones = np.ones(len(masks))
        flag = self.to_tensor(ones - masks)
        
        #print(value_t_p1.size())
        #print(flag.size())
        #print(tensor_rewards.size())
        values = tensor_rewards + self.config["gamma"] * value_t_p1 * flag
        values = self.to_array(values)
        
        assert isinstance(values, np.ndarray)
        assert values.shape == (N,)
        
        # [TODO] Compute the baseline by feeding obs to critic
        tensor_obs = self.to_tensor(obs)
        baselines = self.to_array(self.baseline(tensor_obs).squeeze())
        
        assert isinstance(baselines, np.ndarray)
        assert baselines.shape == (N,)
        
        # [TODO] Compute the advantages using values and baselines
        advantages = values - baselines
        
        if self.config["normalize_advantage"]:
            advantages = (advantages - advantages.mean()) / max(advantages.std(), 1e-6)
        
        # We passed part of numpy array and part of torch tensor
        # to the following modules.
        processed_samples = samples
        processed_samples["advantages"] = advantages
        processed_samples["tensor_next_obs"] = tensor_next_obs
        processed_samples["tensor_obs"] = tensor_obs
        processed_samples["tensor_rewards"] = tensor_rewards
        processed_samples["tensor_masks"] = self.to_tensor(masks)
        process_info = {
            "mean_baselines": float(np.mean(baselines)),
            "advantages_std": float(advantages.std())
        }  # You can add value here so that it will be printed automatically.
        return processed_samples, process_info
        
    def update_baseline(self, processed_samples):
        # Use a bootstrapped target values and update the critic.
        # Compute the target values r(s, a) + gamma * V(s') by calling
        # the critic to compute V(s').
        reward = processed_samples["tensor_rewards"]
        obs = processed_samples["tensor_obs"]
        next_obs = processed_samples["tensor_next_obs"]
        masks = processed_samples["tensor_masks"]
        
        assert masks.shape == reward.shape
        assert next_obs.shape == obs.shape
        
        losses = []
        
        for _ in range(self.config["num_critic_updates"]):  # Train critic for 10 iteration
            self.baseline.eval()
            
            # Predict the values of next state
            values_next = self.baseline(next_obs).reshape(reward.shape)  # a tensor
            
            assert values_next.shape == reward.shape  # tensor shape should equal
            
            # [TODO] Compute the target of critic using reward, masks
            # and values_next (don't forget gamma)
            # Hint: the masks are all False (that is, zero) when the state is not
            #  terminal state, and are True (one) when is. So we can use (1-masks)
            #  as a multiplier to apply to values_next when computing the target.
            target = reward + self.config["gamma"] * values_next * (1 - masks)
            
            target = target.detach()
            self.baseline.train()

            for _ in range(self.config["num_critic_update_steps"]):
                # [TODO] Uncomment the whole section
                
                baselines = self.baseline(obs).reshape(reward.shape)
                loss = self.baseline_loss(input=baselines, target=target)
                self.baseline_optimizer.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_norm_(
                    self.baseline.parameters(), self.config["clip_gradient"]
                )
                self.baseline_optimizer.step()
                losses.append(loss.item())
            
        self.baseline.eval()
        return {"critic_loss": np.mean(losses)}

# %%
# Run this cell without modification

ac_trainer, ac_result = run(ActorCriticTrainer, dict(
    learning_rate=0.01,
    max_episode_length=200,
    train_batch_size=200,
), 195.0)
# Out:
# === ActorCriticTrainer CartPole-v0 Training Start ===
# Config:
#   checked: true
#   clip_gradient: 10.0
#   env_name: CartPole-v0
#   evaluate_interval: 10
#   evaluate_num_episodes: 50
#   gamma: 0.99
#   hidden_units: 64
#   learning_rate: 0.01
#   max_episode_length: 200
#   max_iteration: 1000
#   normalize_advantage: true
#   num_critic_update_steps: 10
#   num_critic_updates: 10
#   seed: 0
#   train_batch_size: 200
#
# === ActorCriticTrainer CartPole-v0 Iteration 0 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 1.6993019128590823
#   evaluate_reward: 20.36
#   iter_episodes: 11
#   iter_time: 0.08865094184875488
#   iter_timesteps: 209
#   iteration: 0
#   mean_advantage: -1.3641400608791396e-15
#   mean_baselines: 0.022191574797034264
#   mean_log_prob: -0.6912497878074646
#   performance: 19.0
#   policy_loss: -12.293457010138283
#   total_episodes: 11
#   total_time: 0.08865094184875488
#   total_timesteps: 209
#   training_episode_length:
#     max: 40.0
#     mean: 19.0
#     min: 12.0
#   training_episode_reward:
#     max: 40.0
#     mean: 19.0
#     min: 12.0
#
# === ActorCriticTrainer CartPole-v0 Iteration 10 ===
# Training Progress:
#   advantages_std: 0.9999999999999998
#   critic_loss: 4.41024878025055
#   evaluate_reward: 44.7
#   iter_episodes: 6
#   iter_time: 0.09823751449584961
#   iter_timesteps: 209
#   iteration: 10
#   mean_advantage: -2.1248287552634574e-18
#   mean_baselines: 17.158479690551758
#   mean_log_prob: -0.6670110821723938
#   performance: 34.833333333333336
#   policy_loss: -31.291209603217656
#   total_episodes: 87
#   total_time: 1.1874494552612305
#   total_timesteps: 2306
#   training_episode_length:
#     max: 61.0
#     mean: 34.833333333333336
#     min: 20.0
#   training_episode_reward:
#     max: 61.0
#     mean: 34.833333333333336
#     min: 20.0
#
# === ActorCriticTrainer CartPole-v0 Iteration 20 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 2.7131300234794615
#   evaluate_reward: 115.02
#   iter_episodes: 3
#   iter_time: 0.11789059638977051
#   iter_timesteps: 305
#   iteration: 20
#   mean_advantage: -1.1648241569837708e-17
#   mean_baselines: 24.053232192993164
#   mean_log_prob: -0.609044075012207
#   performance: 101.66666666666667
#   policy_loss: -6.40565206822622
#   total_episodes: 129
#   total_time: 2.5250136852264404
#   total_timesteps: 4884
#   training_episode_length:
#     max: 116.0
#     mean: 101.66666666666667
#     min: 75.0
#   training_episode_reward:
#     max: 116.0
#     mean: 101.66666666666667
#     min: 75.0
#
# === ActorCriticTrainer CartPole-v0 Iteration 30 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 8.285697884559632
#   evaluate_reward: 162.74
#   iter_episodes: 2
#   iter_time: 0.12819933891296387
#   iter_timesteps: 361
#   iteration: 30
#   mean_advantage: -1.4761968194461916e-17
#   mean_baselines: 48.073646545410156
#   mean_log_prob: -0.5945262312889099
#   performance: 180.5
#   policy_loss: -3.302996312324505
#   total_episodes: 152
#   total_time: 4.404248952865601
#   total_timesteps: 7852
#   training_episode_length:
#     max: 200.0
#     mean: 180.5
#     min: 161.0
#   training_episode_reward:
#     max: 200.0
#     mean: 180.5
#     min: 161.0
#
# === ActorCriticTrainer CartPole-v0 Iteration 40 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 1.0501830351352692
#   evaluate_reward: 191.5
#   iter_episodes: 2
#   iter_time: 0.1370549201965332
#   iter_timesteps: 400
#   iteration: 40
#   mean_advantage: 4.4408920985006264e-17
#   mean_baselines: 40.09052658081055
#   mean_log_prob: -0.555570662021637
#   performance: 200.0
#   policy_loss: 17.029273549692462
#   total_episodes: 173
#   total_time: 6.692699670791626
#   total_timesteps: 11245
#   training_episode_length:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#   training_episode_reward:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#
# === ActorCriticTrainer CartPole-v0 Iteration 50 ===
# Training Progress:
#   advantages_std: 0.9999999999999999
#   critic_loss: 13.315020499229432
#   evaluate_reward: 179.26
#   iter_episodes: 2
#   iter_time: 0.1286172866821289
#   iter_timesteps: 363
#   iteration: 50
#   mean_advantage: 4.893545012121902e-18
#   mean_baselines: 67.66947174072266
#   mean_log_prob: -0.5446671843528748
#   performance: 181.5
#   policy_loss: 7.079317636747616
#   total_episodes: 193
#   total_time: 9.266305208206177
#   total_timesteps: 15181
#   training_episode_length:
#     max: 182.0
#     mean: 181.5
#     min: 181.0
#   training_episode_reward:
#     max: 182.0
#     mean: 181.5
#     min: 181.0
#
# === ActorCriticTrainer CartPole-v0 Iteration 60 ===
# Training Progress:
#   advantages_std: 0.9999999999999999
#   critic_loss: 3.752860608100891
#   evaluate_reward: 169.76
#   iter_episodes: 2
#   iter_time: 0.11596441268920898
#   iter_timesteps: 312
#   iteration: 60
#   mean_advantage: 2.846725704167068e-17
#   mean_baselines: 46.31793975830078
#   mean_log_prob: -0.5412290692329407
#   performance: 156.0
#   policy_loss: 17.857049131260755
#   total_episodes: 213
#   total_time: 11.589065790176392
#   total_timesteps: 18387
#   training_episode_length:
#     max: 200.0
#     mean: 156.0
#     min: 112.0
#   training_episode_reward:
#     max: 200.0
#     mean: 156.0
#     min: 112.0
#
# === ActorCriticTrainer CartPole-v0 Iteration 70 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 12.150531225204467
#   evaluate_reward: 198.98
#   iter_episodes: 2
#   iter_time: 0.11957120895385742
#   iter_timesteps: 336
#   iteration: 70
#   mean_advantage: 1.586032892321652e-17
#   mean_baselines: 62.48573684692383
#   mean_log_prob: -0.477872759103775
#   performance: 168.0
#   policy_loss: -2.8246858347100896
#   total_episodes: 233
#   total_time: 13.921782970428467
#   total_timesteps: 22077
#   training_episode_length:
#     max: 200.0
#     mean: 168.0
#     min: 136.0
#   training_episode_reward:
#     max: 200.0
#     mean: 168.0
#     min: 136.0
#
# In 70 iteration, cupretty_printrrent mean episode reward 198.980 is greater than reward threshold 195.0. Congratulation! Now we exit the training process.

# %%
# Run this cell without modification

pg_result_na["label"] = "Pure PG"
pgwb_result_wb["label"] = "PG with Baseline"
ac_result["label"] = "Actor-critic"
pg_result = pd.concat([pg_result_na, pgwb_result_wb, ac_result])
ax = sns.lineplot(
    x="total_timesteps", 
    y="performance", 
    data=pg_result, hue="label",
)
ax.set_title("Policy Gradient")
# Out:
# /home/shi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# Text(0.5, 1.0, 'Policy Gradient')

# %% [markdown]
# ### Section 4.2 -- Land on the Moon!
#
# (5 / 100 points)
#
# Let's try to land on the moon! In this section, we will try a harder environment: "LunarLander-v2". The agent needs to control the lander to land on a small interval of the moon marked by the flags. Due to the complex dynamic of rocket, the environment is hard to solve and it may take hours for you to train.
#
# The environment provides a 8-element vector as observation, which is different from the image observation provided by the following Pong environment in the next setion.

# %%
# Run this cell without modification
e = gym.make("LunarLander-v2"); e.reset()
frames = []
for _ in range(1000):
    frames.append(e.render("rgb_array"))
    if e.step(e.action_space.sample())[2]: break
e.close();animate(frames);del e

# %%
import gym

# %%
e = gym.make("LunarLander-v2")

# %%
e.observation_space
# Out:
# Box(8,)

# %%
# Run this cell without modification

ac_trainer_lander, ac_result_lander = run(ActorCriticTrainer, dict(
    env_name="LunarLander-v2",
    max_iteration=500,
    learning_rate=0.005,
    max_episode_length=1000,
    train_batch_size=10000,
    normalize_advantage=True,
    evaluate_interval=1,
    evaluate_num_episodes=5,
), 200)

# Hint: 1. This would take hours to train on personal laptop.
#       2. Episode reward should greater than 0 after 80 iterations.
#       3. We are using purely on-policy algorithm, so we expect the performance 
#          to be highly unstable.
# Out:
# === ActorCriticTrainer LunarLander-v2 Training Start ===
# Config:
#   checked: true
#   clip_gradient: 10.0
#   env_name: LunarLander-v2
#   evaluate_interval: 1
#   evaluate_num_episodes: 5
#   gamma: 0.99
#   hidden_units: 64
#   learning_rate: 0.005
#   max_episode_length: 1000
#   max_iteration: 500
#   normalize_advantage: true
#   num_critic_update_steps: 10
#   num_critic_updates: 10
#   seed: 0
#   train_batch_size: 10000
#
# === ActorCriticTrainer LunarLander-v2 Iteration 0 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 91.77507335662841
#   evaluate_reward: -199.4163404196225
#   iter_episodes: 108
#   iter_time: 3.2872884273529053
#   iter_timesteps: 10091
#   iteration: 0
#   mean_advantage: 3.309434999576326e-17
#   mean_baselines: -0.49405917525291443
#   mean_log_prob: -1.3821568489074707
#   performance: -173.8026831349211
#   policy_loss: 19.066642842267274
#   total_episodes: 108
#   total_time: 3.2872884273529053
#   total_timesteps: 10091
#   training_episode_length:
#     max: 150.0
#     mean: 93.43518518518519
#     min: 57.0
#   training_episode_reward:
#     max: 32.85363946305074
#     mean: -173.8026831349211
#     min: -446.7040970281293
#
# === ActorCriticTrainer LunarLander-v2 Iteration 1 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 33.43626541137695
#   evaluate_reward: -134.30828631726126
#   iter_episodes: 106
#   iter_time: 3.2455952167510986
#   iter_timesteps: 10083
#   iteration: 1
#   mean_advantage: 1.074658010546616e-17
#   mean_baselines: -21.42962074279785
#   mean_log_prob: -1.379817008972168
#   performance: -180.92612758818734
#   policy_loss: -70.95947604043302
#   total_episodes: 214
#   total_time: 6.532883644104004
#   total_timesteps: 20174
#   training_episode_length:
#     max: 161.0
#     mean: 95.12264150943396
#     min: 59.0
#   training_episode_reward:
#     max: -16.155725284975176
#     mean: -180.92612758818734
#     min: -497.51845680795464
#
# === ActorCriticTrainer LunarLander-v2 Iteration 2 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 35.27212661743164
#   evaluate_reward: -197.03106889371685
#   iter_episodes: 105
#   iter_time: 3.256565809249878
#   iter_timesteps: 10084
#   iteration: 2
#   mean_advantage: 1.5325569717158052e-17
#   mean_baselines: -39.48945617675781
#   mean_log_prob: -1.3754528760910034
#   performance: -157.29902243563708
#   policy_loss: -246.7854449347712
#   total_episodes: 319
#   total_time: 9.789449453353882
#   total_timesteps: 30258
#   training_episode_length:
#     max: 156.0
#     mean: 96.03809523809524
#     min: 60.0
#   training_episode_reward:
#     max: -31.77034735495981
#     mean: -157.29902243563708
#     min: -464.8137339908904
#
# === ActorCriticTrainer LunarLander-v2 Iteration 3 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 43.27979549407959
#   evaluate_reward: -131.98282438610065
#   iter_episodes: 100
#   iter_time: 3.328723907470703
#   iter_timesteps: 10005
#   iteration: 3
#   mean_advantage: -6.214141866967393e-19
#   mean_baselines: -52.59252166748047
#   mean_log_prob: -1.3682459592819214
#   performance: -177.06804639688917
#   policy_loss: -243.33097477868142
#   total_episodes: 419
#   total_time: 13.118173360824585
#   total_timesteps: 40263
#   training_episode_length:
#     max: 153.0
#     mean: 100.05
#     min: 57.0
#   training_episode_reward:
#     max: 7.580544863826987
#     mean: -177.06804639688917
#     min: -493.6710410489666
#
# === ActorCriticTrainer LunarLander-v2 Iteration 4 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 38.453465881347654
#   evaluate_reward: -167.89709843136922
#   iter_episodes: 89
#   iter_time: 3.6843245029449463
#   iter_timesteps: 10104
#   iteration: 4
#   mean_advantage: 1.1954895593746736e-17
#   mean_baselines: -59.84122085571289
#   mean_log_prob: -1.362644910812378
#   performance: -147.11412866526035
#   policy_loss: -342.99435326868473
#   total_episodes: 508
#   total_time: 16.80249786376953
#   total_timesteps: 50367
#   training_episode_length:
#     max: 1000.0
#     mean: 113.52808988764045
#     min: 62.0
#   training_episode_reward:
#     max: 50.423657380180984
#     mean: -147.11412866526035
#     min: -485.3261417587079
#
# === ActorCriticTrainer LunarLander-v2 Iteration 5 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 45.3321410369873
#   evaluate_reward: -172.25285038265832
#   iter_episodes: 92
#   iter_time: 3.346693754196167
#   iter_timesteps: 10144
#   iteration: 5
#   mean_advantage: -2.801824667823739e-18
#   mean_baselines: -65.58301544189453
#   mean_log_prob: -1.3507843017578125
#   performance: -172.35049423166058
#   policy_loss: -337.14572606985746
#   total_episodes: 600
#   total_time: 20.1491916179657
#   total_timesteps: 60511
#   training_episode_length:
#     max: 174.0
#     mean: 110.26086956521739
#     min: 69.0
#   training_episode_reward:
#     max: -10.258166801025496
#     mean: -172.35049423166058
#     min: -477.51366400114466
#
# === ActorCriticTrainer LunarLander-v2 Iteration 6 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 41.895519714355466
#   evaluate_reward: -96.1625048623273
#   iter_episodes: 92
#   iter_time: 3.3019471168518066
#   iter_timesteps: 10047
#   iteration: 6
#   mean_advantage: -4.4643187214946074e-18
#   mean_baselines: -64.69731903076172
#   mean_log_prob: -1.3386400938034058
#   performance: -154.36042985287816
#   policy_loss: -388.6451681414186
#   total_episodes: 692
#   total_time: 23.451138734817505
#   total_timesteps: 70558
#   training_episode_length:
#     max: 265.0
#     mean: 109.20652173913044
#     min: 65.0
#   training_episode_reward:
#     max: 1.4472065268528098
#     mean: -154.36042985287816
#     min: -402.1095006544126
#
# === ActorCriticTrainer LunarLander-v2 Iteration 7 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 40.49582462310791
#   evaluate_reward: -155.2517734203303
#   iter_episodes: 88
#   iter_time: 4.547810316085815
#   iter_timesteps: 10034
#   iteration: 7
#   mean_advantage: 7.346901418687502e-18
#   mean_baselines: -66.60518646240234
#   mean_log_prob: -1.3267409801483154
#   performance: -173.21377394610968
#   policy_loss: -272.31093078582785
#   total_episodes: 780
#   total_time: 27.99894905090332
#   total_timesteps: 80592
#   training_episode_length:
#     max: 219.0
#     mean: 114.02272727272727
#     min: 71.0
#   training_episode_reward:
#     max: 9.16881561913064
#     mean: -173.21377394610968
#     min: -454.41347116983184
#
# === ActorCriticTrainer LunarLander-v2 Iteration 8 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 48.99640201568604
#   evaluate_reward: -154.49002053730777
#   iter_episodes: 85
#   iter_time: 3.4996020793914795
#   iter_timesteps: 10065
#   iteration: 8
#   mean_advantage: -4.500456970164569e-18
#   mean_baselines: -72.70687866210938
#   mean_log_prob: -1.306519865989685
#   performance: -181.74383968279597
#   policy_loss: -278.06935801482643
#   total_episodes: 865
#   total_time: 31.4985511302948
#   total_timesteps: 90657
#   training_episode_length:
#     max: 196.0
#     mean: 118.41176470588235
#     min: 64.0
#   training_episode_reward:
#     max: 9.120921135280184
#     mean: -181.74383968279597
#     min: -432.6043249360421
#
# === ActorCriticTrainer LunarLander-v2 Iteration 9 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 70.56319091796875
#   evaluate_reward: -212.36117047716888
#   iter_episodes: 75
#   iter_time: 4.229959726333618
#   iter_timesteps: 10064
#   iteration: 9
#   mean_advantage: 2.1180725430050683e-17
#   mean_baselines: -77.11665344238281
#   mean_log_prob: -1.311064600944519
#   performance: -182.2696372161198
#   policy_loss: -126.8693574791958
#   total_episodes: 940
#   total_time: 35.72851085662842
#   total_timesteps: 100721
#   training_episode_length:
#     max: 1000.0
#     mean: 134.18666666666667
#     min: 67.0
#   training_episode_reward:
#     max: 93.64840922089738
#     mean: -182.2696372161198
#     min: -436.69398939037006
#
# === ActorCriticTrainer LunarLander-v2 Iteration 10 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 54.96313056945801
#   evaluate_reward: -159.96587259266576
#   iter_episodes: 82
#   iter_time: 4.976366758346558
#   iter_timesteps: 10163
#   iteration: 10
#   mean_advantage: -4.02555529444426e-18
#   mean_baselines: -71.98207092285156
#   mean_log_prob: -1.2924681901931763
#   performance: -153.45891829473575
#   policy_loss: -306.59291656026994
#   total_episodes: 1022
#   total_time: 40.704877614974976
#   total_timesteps: 110884
#   training_episode_length:
#     max: 395.0
#     mean: 123.9390243902439
#     min: 70.0
#   training_episode_reward:
#     max: 8.204968364701955
#     mean: -153.45891829473575
#     min: -398.97618921371463
#
# === ActorCriticTrainer LunarLander-v2 Iteration 11 ===
# Training Progress:
#   advantages_std: 0.9999999999999999
#   critic_loss: 64.59589176177978
#   evaluate_reward: -226.02365670083236
#   iter_episodes: 80
#   iter_time: 3.5916428565979004
#   iter_timesteps: 10120
#   iteration: 11
#   mean_advantage: -8.688701931849052e-18
#   mean_baselines: -86.20621490478516
#   mean_log_prob: -1.26999032497406
#   performance: -189.3785443253706
#   policy_loss: -112.84368205314455
#   total_episodes: 1102
#   total_time: 44.296520471572876
#   total_timesteps: 121004
#   training_episode_length:
#     max: 208.0
#     mean: 126.5
#     min: 71.0
#   training_episode_reward:
#     max: 4.20801027217702
#     mean: -189.3785443253706
#     min: -504.1844089755271
#
# === ActorCriticTrainer LunarLander-v2 Iteration 12 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 79.49916351318359
#   evaluate_reward: -261.5023708134289
#   iter_episodes: 76
#   iter_time: 3.713244676589966
#   iter_timesteps: 10123
#   iteration: 12
#   mean_advantage: 3.5797371850009986e-17
#   mean_baselines: -87.97942352294922
#   mean_log_prob: -1.264127254486084
#   performance: -204.28655051389956
#   policy_loss: -114.42676705085078
#   total_episodes: 1178
#   total_time: 48.00976514816284
#   total_timesteps: 131127
#   training_episode_length:
#     max: 259.0
#     mean: 133.19736842105263
#     min: 80.0
#   training_episode_reward:
#     max: -14.390122158517343
#     mean: -204.28655051389956
#     min: -561.8599895339939
#
# === ActorCriticTrainer LunarLander-v2 Iteration 13 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 60.3161124420166
#   evaluate_reward: -168.13411671111604
#   iter_episodes: 68
#   iter_time: 4.2389421463012695
#   iter_timesteps: 10035
#   iteration: 13
#   mean_advantage: 3.1862902948883417e-18
#   mean_baselines: -93.46268463134766
#   mean_log_prob: -1.260543704032898
#   performance: -216.1154067926997
#   policy_loss: -13.214722816474819
#   total_episodes: 1246
#   total_time: 52.24870729446411
#   total_timesteps: 141162
#   training_episode_length:
#     max: 1000.0
#     mean: 147.5735294117647
#     min: 81.0
#   training_episode_reward:
#     max: -7.343311231711851
#     mean: -216.1154067926997
#     min: -556.5080949270493
#
# === ActorCriticTrainer LunarLander-v2 Iteration 14 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 84.82179237365723
#   evaluate_reward: -195.19937777607046
#   iter_episodes: 76
#   iter_time: 3.6928412914276123
#   iter_timesteps: 10051
#   iteration: 14
#   mean_advantage: 8.880900525307192e-18
#   mean_baselines: -91.84770202636719
#   mean_log_prob: -1.2314656972885132
#   performance: -199.31166658624298
#   policy_loss: -152.88448515275715
#   total_episodes: 1322
#   total_time: 55.941548585891724
#   total_timesteps: 151213
#   training_episode_length:
#     max: 237.0
#     mean: 132.25
#     min: 76.0
#   training_episode_reward:
#     max: 9.725269969502591
#     mean: -199.31166658624298
#     min: -484.0149139755946
#
# === ActorCriticTrainer LunarLander-v2 Iteration 15 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 69.30548500061035
#   evaluate_reward: -295.0407594021717
#   iter_episodes: 74
#   iter_time: 3.5850729942321777
#   iter_timesteps: 10141
#   iteration: 15
#   mean_advantage: 3.459525448984809e-18
#   mean_baselines: -100.61959838867188
#   mean_log_prob: -1.238189697265625
#   performance: -234.85461867119415
#   policy_loss: -3.0673275243484817
#   total_episodes: 1396
#   total_time: 59.5266215801239
#   total_timesteps: 161354
#   training_episode_length:
#     max: 217.0
#     mean: 137.04054054054055
#     min: 72.0
#   training_episode_reward:
#     max: -8.762065364673958
#     mean: -234.85461867119415
#     min: -725.6226228629674
#
# === ActorCriticTrainer LunarLander-v2 Iteration 16 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 55.11721782684326
#   evaluate_reward: -141.7525478701938
#   iter_episodes: 71
#   iter_time: 4.186550855636597
#   iter_timesteps: 10011
#   iteration: 16
#   mean_advantage: -1.1001310962223107e-17
#   mean_baselines: -93.54637908935547
#   mean_log_prob: -1.2595449686050415
#   performance: -183.5884288790722
#   policy_loss: -3.068972057302353
#   total_episodes: 1467
#   total_time: 63.7131724357605
#   total_timesteps: 171365
#   training_episode_length:
#     max: 1000.0
#     mean: 141.0
#     min: 75.0
#   training_episode_reward:
#     max: 28.64807608436604
#     mean: -183.5884288790722
#     min: -428.67335905627397
#
# === ActorCriticTrainer LunarLander-v2 Iteration 17 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 48.73181358337402
#   evaluate_reward: -137.9846211741545
#   iter_episodes: 74
#   iter_time: 3.6209473609924316
#   iter_timesteps: 10086
#   iteration: 17
#   mean_advantage: -1.1800109879022089e-17
#   mean_baselines: -86.6103286743164
#   mean_log_prob: -1.2482671737670898
#   performance: -180.21044037536006
#   policy_loss: -216.10837139732402
#   total_episodes: 1541
#   total_time: 67.33411979675293
#   total_timesteps: 181451
#   training_episode_length:
#     max: 248.0
#     mean: 136.2972972972973
#     min: 82.0
#   training_episode_reward:
#     max: 14.357765093548878
#     mean: -180.21044037536006
#     min: -464.0567171998352
#
# === ActorCriticTrainer LunarLander-v2 Iteration 18 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 58.316537132263186
#   evaluate_reward: -187.03204509672648
#   iter_episodes: 80
#   iter_time: 3.5660171508789062
#   iter_timesteps: 10139
#   iteration: 18
#   mean_advantage: 7.00801593608936e-18
#   mean_baselines: -81.17143249511719
#   mean_log_prob: -1.2403291463851929
#   performance: -161.08105926247066
#   policy_loss: -243.32720625387597
#   total_episodes: 1621
#   total_time: 70.90013694763184
#   total_timesteps: 191590
#   training_episode_length:
#     max: 216.0
#     mean: 126.7375
#     min: 80.0
#   training_episode_reward:
#     max: 25.053292497206556
#     mean: -161.08105926247066
#     min: -410.5193573343055
#
# === ActorCriticTrainer LunarLander-v2 Iteration 19 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 60.81681545257568
#   evaluate_reward: -170.6678319855052
#   iter_episodes: 83
#   iter_time: 3.5071544647216797
#   iter_timesteps: 10025
#   iteration: 19
#   mean_advantage: -1.506137968568791e-18
#   mean_baselines: -83.90287017822266
#   mean_log_prob: -1.2492657899856567
#   performance: -159.2611108522849
#   policy_loss: -392.89891352695815
#   total_episodes: 1704
#   total_time: 74.40729141235352
#   total_timesteps: 201615
#   training_episode_length:
#     max: 208.0
#     mean: 120.78313253012048
#     min: 77.0
#   training_episode_reward:
#     max: 29.83031435449223
#     mean: -159.2611108522849
#     min: -508.60115560952744
#
# === ActorCriticTrainer LunarLander-v2 Iteration 20 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 49.71548137664795
#   evaluate_reward: -94.48278931014305
#   iter_episodes: 67
#   iter_time: 4.563770294189453
#   iter_timesteps: 10023
#   iteration: 20
#   mean_advantage: 9.747543267186848e-19
#   mean_baselines: -83.9105453491211
#   mean_log_prob: -1.2588474750518799
#   performance: -156.0881608915952
#   policy_loss: -377.2607270316918
#   total_episodes: 1771
#   total_time: 78.97106170654297
#   total_timesteps: 211638
#   training_episode_length:
#     max: 1000.0
#     mean: 149.59701492537314
#     min: 79.0
#   training_episode_reward:
#     max: 52.80063301431334
#     mean: -156.0881608915952
#     min: -461.4301671520132
#
# === ActorCriticTrainer LunarLander-v2 Iteration 21 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 52.09084747314453
#   evaluate_reward: -30.308964040754677
#   iter_episodes: 86
#   iter_time: 3.5423333644866943
#   iter_timesteps: 10023
#   iteration: 21
#   mean_advantage: 1.0101999385993642e-17
#   mean_baselines: -78.06237030029297
#   mean_log_prob: -1.2447601556777954
#   performance: -138.60393861668123
#   policy_loss: -750.0573283816934
#   total_episodes: 1857
#   total_time: 82.51339507102966
#   total_timesteps: 221661
#   training_episode_length:
#     max: 267.0
#     mean: 116.54651162790698
#     min: 73.0
#   training_episode_reward:
#     max: 47.33067563222647
#     mean: -138.60393861668123
#     min: -392.0638212888948
#
# === ActorCriticTrainer LunarLander-v2 Iteration 22 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 37.242972412109374
#   evaluate_reward: -93.36995552689828
#   iter_episodes: 85
#   iter_time: 3.629500389099121
#   iter_timesteps: 10085
#   iteration: 22
#   mean_advantage: 1.4927738437200914e-17
#   mean_baselines: -63.903568267822266
#   mean_log_prob: -1.2501252889633179
#   performance: -113.51645366358508
#   policy_loss: -930.0500963951623
#   total_episodes: 1942
#   total_time: 86.14289546012878
#   total_timesteps: 231746
#   training_episode_length:
#     max: 174.0
#     mean: 118.6470588235294
#     min: 72.0
#   training_episode_reward:
#     max: 26.977387289935038
#     mean: -113.51645366358508
#     min: -365.319772786636
#
# === ActorCriticTrainer LunarLander-v2 Iteration 23 ===
# Training Progress:
#   advantages_std: 0.9999999999999999
#   critic_loss: 47.814876556396484
#   evaluate_reward: -191.64718191723492
#   iter_episodes: 85
#   iter_time: 3.6019911766052246
#   iter_timesteps: 10111
#   iteration: 23
#   mean_advantage: 1.2676812203834865e-17
#   mean_baselines: -70.69818878173828
#   mean_log_prob: -1.2354365587234497
#   performance: -121.96431638967366
#   policy_loss: -914.9006023347995
#   total_episodes: 2027
#   total_time: 89.74488663673401
#   total_timesteps: 241857
#   training_episode_length:
#     max: 172.0
#     mean: 118.95294117647059
#     min: 73.0
#   training_episode_reward:
#     max: 11.277712649450677
#     mean: -121.96431638967366
#     min: -321.332674769288
#
# === ActorCriticTrainer LunarLander-v2 Iteration 24 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 38.94294200897217
#   evaluate_reward: -107.01531579469501
#   iter_episodes: 89
#   iter_time: 3.5483925342559814
#   iter_timesteps: 10053
#   iteration: 24
#   mean_advantage: 2.606312879852153e-18
#   mean_baselines: -66.02057647705078
#   mean_log_prob: -1.2321487665176392
#   performance: -119.28132345935633
#   policy_loss: -907.2274127250985
#   total_episodes: 2116
#   total_time: 93.29327917098999
#   total_timesteps: 251910
#   training_episode_length:
#     max: 185.0
#     mean: 112.95505617977528
#     min: 69.0
#   training_episode_reward:
#     max: 31.777985733706913
#     mean: -119.28132345935633
#     min: -437.23003193561124
#
# === ActorCriticTrainer LunarLander-v2 Iteration 25 ===
# Training Progress:
#   advantages_std: 0.9999999999999999
#   critic_loss: 46.81547916412354
#   evaluate_reward: -117.57878675626634
#   iter_episodes: 79
#   iter_time: 4.044278621673584
#   iter_timesteps: 10077
#   iteration: 25
#   mean_advantage: 1.9390617478815874e-18
#   mean_baselines: -65.26304626464844
#   mean_log_prob: -1.2220438718795776
#   performance: -122.86125328222748
#   policy_loss: -646.2003388798072
#   total_episodes: 2195
#   total_time: 97.33755779266357
#   total_timesteps: 261987
#   training_episode_length:
#     max: 1000.0
#     mean: 127.55696202531645
#     min: 75.0
#   training_episode_reward:
#     max: 74.90770945649746
#     mean: -122.86125328222748
#     min: -300.12282150060366
#
# === ActorCriticTrainer LunarLander-v2 Iteration 26 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 50.98148361206054
#   evaluate_reward: -93.01450970772062
#   iter_episodes: 85
#   iter_time: 3.6154215335845947
#   iter_timesteps: 10058
#   iteration: 26
#   mean_advantage: -8.830566908929462e-19
#   mean_baselines: -57.45227813720703
#   mean_log_prob: -1.1951547861099243
#   performance: -118.47868366127815
#   policy_loss: -949.3629712777683
#   total_episodes: 2280
#   total_time: 100.95297932624817
#   total_timesteps: 272045
#   training_episode_length:
#     max: 179.0
#     mean: 118.32941176470588
#     min: 81.0
#   training_episode_reward:
#     max: 40.92037199512981
#     mean: -118.47868366127815
#     min: -383.72501814360436
#
# === ActorCriticTrainer LunarLander-v2 Iteration 27 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 40.35330890655518
#   evaluate_reward: -59.05851926858636
#   iter_episodes: 84
#   iter_time: 3.596022844314575
#   iter_timesteps: 10099
#   iteration: 27
#   mean_advantage: -3.473913018928107e-18
#   mean_baselines: -61.42488098144531
#   mean_log_prob: -1.1882069110870361
#   performance: -97.33445792061659
#   policy_loss: -924.0786169106067
#   total_episodes: 2364
#   total_time: 104.54900217056274
#   total_timesteps: 282144
#   training_episode_length:
#     max: 171.0
#     mean: 120.22619047619048
#     min: 80.0
#   training_episode_reward:
#     max: 41.36060109684766
#     mean: -97.33445792061659
#     min: -315.4342005832662
#
# === ActorCriticTrainer LunarLander-v2 Iteration 28 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 39.317251167297364
#   evaluate_reward: -150.97878744581044
#   iter_episodes: 72
#   iter_time: 4.891357183456421
#   iter_timesteps: 10809
#   iteration: 28
#   mean_advantage: -3.9441728324179864e-18
#   mean_baselines: -60.98912811279297
#   mean_log_prob: -1.2131255865097046
#   performance: -98.60412956443805
#   policy_loss: -827.7990875228446
#   total_episodes: 2436
#   total_time: 109.44035935401917
#   total_timesteps: 292953
#   training_episode_length:
#     max: 1000.0
#     mean: 150.125
#     min: 85.0
#   training_episode_reward:
#     max: 117.82853966265512
#     mean: -98.60412956443805
#     min: -289.47456320647143
#
# === ActorCriticTrainer LunarLander-v2 Iteration 29 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 30.19898775100708
#   evaluate_reward: -67.88026323096229
#   iter_episodes: 75
#   iter_time: 4.4839863777160645
#   iter_timesteps: 10034
#   iteration: 29
#   mean_advantage: 5.8421143811250015e-18
#   mean_baselines: -53.73432922363281
#   mean_log_prob: -1.1819638013839722
#   performance: -82.65833524655018
#   policy_loss: -1194.2267577594089
#   total_episodes: 2511
#   total_time: 113.92434573173523
#   total_timesteps: 302987
#   training_episode_length:
#     max: 1000.0
#     mean: 133.78666666666666
#     min: 74.0
#   training_episode_reward:
#     max: 76.7845238350646
#     mean: -82.65833524655018
#     min: -311.94139529565837
#
# === ActorCriticTrainer LunarLander-v2 Iteration 30 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 46.43099925994873
#   evaluate_reward: -64.29356994728678
#   iter_episodes: 76
#   iter_time: 4.320044755935669
#   iter_timesteps: 10014
#   iteration: 30
#   mean_advantage: 1.1751911385087538e-17
#   mean_baselines: -54.7894401550293
#   mean_log_prob: -1.1580826044082642
#   performance: -79.37483111602
#   policy_loss: -879.2816351206144
#   total_episodes: 2587
#   total_time: 118.2443904876709
#   total_timesteps: 313001
#   training_episode_length:
#     max: 1000.0
#     mean: 131.76315789473685
#     min: 68.0
#   training_episode_reward:
#     max: 96.84833445262827
#     mean: -79.37483111602
#     min: -393.78988727086954
#
# === ActorCriticTrainer LunarLander-v2 Iteration 31 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 37.55356708526611
#   evaluate_reward: -43.92891840309453
#   iter_episodes: 79
#   iter_time: 4.572443008422852
#   iter_timesteps: 10588
#   iteration: 31
#   mean_advantage: 6.71083052285701e-18
#   mean_baselines: -52.76485061645508
#   mean_log_prob: -1.1461337804794312
#   performance: -81.62523858162261
#   policy_loss: -1096.3217009399734
#   total_episodes: 2666
#   total_time: 122.81683349609375
#   total_timesteps: 323589
#   training_episode_length:
#     max: 1000.0
#     mean: 134.0253164556962
#     min: 82.0
#   training_episode_reward:
#     max: 48.34206780129926
#     mean: -81.62523858162261
#     min: -365.651046224742
#
# === ActorCriticTrainer LunarLander-v2 Iteration 32 ===
# Training Progress:
#   advantages_std: 1.0000000000000002
#   critic_loss: 39.65701141357422
#   evaluate_reward: -63.866454066958966
#   iter_episodes: 73
#   iter_time: 3.78808856010437
#   iter_timesteps: 10113
#   iteration: 32
#   mean_advantage: -1.6862479638329284e-17
#   mean_baselines: -48.990638732910156
#   mean_log_prob: -1.1240816116333008
#   performance: -83.89484802389553
#   policy_loss: -1125.3923391154692
#   total_episodes: 2739
#   total_time: 126.60492205619812
#   total_timesteps: 333702
#   training_episode_length:
#     max: 235.0
#     mean: 138.53424657534248
#     min: 84.0
#   training_episode_reward:
#     max: 48.00160434483459
#     mean: -83.89484802389553
#     min: -327.1331911715157
#
# === ActorCriticTrainer LunarLander-v2 Iteration 33 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 35.84574943542481
#   evaluate_reward: -80.25180177288868
#   iter_episodes: 57
#   iter_time: 5.284679651260376
#   iter_timesteps: 10053
#   iteration: 33
#   mean_advantage: 2.3854389069833267e-18
#   mean_baselines: -56.24631881713867
#   mean_log_prob: -1.1517521142959595
#   performance: -80.31408686745326
#   policy_loss: -806.0479094498139
#   total_episodes: 2796
#   total_time: 131.8896017074585
#   total_timesteps: 343755
#   training_episode_length:
#     max: 1000.0
#     mean: 176.3684210526316
#     min: 81.0
#   training_episode_reward:
#     max: 86.50398432308965
#     mean: -80.31408686745326
#     min: -410.49907836595423
#
# === ActorCriticTrainer LunarLander-v2 Iteration 34 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 34.557289924621585
#   evaluate_reward: -35.68403558123582
#   iter_episodes: 68
#   iter_time: 4.463535308837891
#   iter_timesteps: 10052
#   iteration: 34
#   mean_advantage: -7.068670272185636e-19
#   mean_baselines: -47.7271614074707
#   mean_log_prob: -1.1084469556808472
#   performance: -68.8829305703106
#   policy_loss: -1408.4781456870535
#   total_episodes: 2864
#   total_time: 136.3531370162964
#   total_timesteps: 353807
#   training_episode_length:
#     max: 1000.0
#     mean: 147.8235294117647
#     min: 86.0
#   training_episode_reward:
#     max: 101.26302296845797
#     mean: -68.8829305703106
#     min: -304.8575239476131
#
# === ActorCriticTrainer LunarLander-v2 Iteration 35 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 39.38766159057617
#   evaluate_reward: -38.50350939529987
#   iter_episodes: 55
#   iter_time: 5.384440898895264
#   iter_timesteps: 10026
#   iteration: 35
#   mean_advantage: 1.0320445431384858e-17
#   mean_baselines: -43.619937896728516
#   mean_log_prob: -1.1217713356018066
#   performance: -62.71395728822083
#   policy_loss: -1056.2217129619232
#   total_episodes: 2919
#   total_time: 141.73757791519165
#   total_timesteps: 363833
#   training_episode_length:
#     max: 1000.0
#     mean: 182.29090909090908
#     min: 87.0
#   training_episode_reward:
#     max: 73.11536087949244
#     mean: -62.71395728822083
#     min: -334.4427591323313
#
# === ActorCriticTrainer LunarLander-v2 Iteration 36 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 41.387064132690426
#   evaluate_reward: -22.6413621652212
#   iter_episodes: 52
#   iter_time: 5.453046560287476
#   iter_timesteps: 10270
#   iteration: 36
#   mean_advantage: 5.3511236337824e-18
#   mean_baselines: -48.502593994140625
#   mean_log_prob: -1.0979353189468384
#   performance: -78.37190597063135
#   policy_loss: -1075.277965773281
#   total_episodes: 2971
#   total_time: 147.19062447547913
#   total_timesteps: 374103
#   training_episode_length:
#     max: 1000.0
#     mean: 197.5
#     min: 93.0
#   training_episode_reward:
#     max: 82.96115971352135
#     mean: -78.37190597063135
#     min: -324.6574933484953
#
# === ActorCriticTrainer LunarLander-v2 Iteration 37 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 30.905060749053956
#   evaluate_reward: -20.868324713159097
#   iter_episodes: 46
#   iter_time: 8.314007759094238
#   iter_timesteps: 10444
#   iteration: 37
#   mean_advantage: 5.612770557277697e-18
#   mean_baselines: -43.053733825683594
#   mean_log_prob: -1.1185752153396606
#   performance: -50.19889609223227
#   policy_loss: -1154.146961606276
#   total_episodes: 3017
#   total_time: 155.50463223457336
#   total_timesteps: 384547
#   training_episode_length:
#     max: 1000.0
#     mean: 227.04347826086956
#     min: 119.0
#   training_episode_reward:
#     max: 83.10624085199548
#     mean: -50.19889609223227
#     min: -285.3640714044957
#
# === ActorCriticTrainer LunarLander-v2 Iteration 38 ===
# Training Progress:
#   advantages_std: 0.9999999999999999
#   critic_loss: 40.07969581604004
#   evaluate_reward: -151.15663716542215
#   iter_episodes: 50
#   iter_time: 6.001946687698364
#   iter_timesteps: 10295
#   iteration: 38
#   mean_advantage: 9.7488257820412e-18
#   mean_baselines: -39.967811584472656
#   mean_log_prob: -1.0562593936920166
#   performance: -73.3111667163841
#   policy_loss: -1164.2418703343972
#   total_episodes: 3067
#   total_time: 161.50657892227173
#   total_timesteps: 394842
#   training_episode_length:
#     max: 1000.0
#     mean: 205.9
#     min: 102.0
#   training_episode_reward:
#     max: 60.915548506503114
#     mean: -73.3111667163841
#     min: -273.4355724166769
#
# === ActorCriticTrainer LunarLander-v2 Iteration 39 ===
# Training Progress:
#   advantages_std: 1.0000000000000002
#   critic_loss: 42.796210594177246
#   evaluate_reward: -121.79241504053618
#   iter_episodes: 35
#   iter_time: 8.175713300704956
#   iter_timesteps: 10061
#   iteration: 39
#   mean_advantage: 4.943642928457113e-18
#   mean_baselines: -42.052040100097656
#   mean_log_prob: -1.102181315422058
#   performance: -110.92752158043585
#   policy_loss: -939.4931282735083
#   total_episodes: 3102
#   total_time: 169.68229222297668
#   total_timesteps: 404903
#   training_episode_length:
#     max: 1000.0
#     mean: 287.45714285714286
#     min: 89.0
#   training_episode_reward:
#     max: 81.23861822327912
#     mean: -110.92752158043585
#     min: -301.1160795482747
#
# === ActorCriticTrainer LunarLander-v2 Iteration 40 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 32.01574586868286
#   evaluate_reward: -164.56328304336006
#   iter_episodes: 36
#   iter_time: 6.995424747467041
#   iter_timesteps: 10051
#   iteration: 40
#   mean_advantage: -1.343180974971834e-17
#   mean_baselines: -41.10975646972656
#   mean_log_prob: -1.0717090368270874
#   performance: -82.58543365311948
#   policy_loss: -1042.8864921548839
#   total_episodes: 3138
#   total_time: 176.67771697044373
#   total_timesteps: 414954
#   training_episode_length:
#     max: 1000.0
#     mean: 279.19444444444446
#     min: 102.0
#   training_episode_reward:
#     max: 106.70392719303995
#     mean: -82.58543365311948
#     min: -311.261764960625
#
# === ActorCriticTrainer LunarLander-v2 Iteration 41 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 27.87889171600342
#   evaluate_reward: -89.93031739526768
#   iter_episodes: 35
#   iter_time: 8.273852109909058
#   iter_timesteps: 10768
#   iteration: 41
#   mean_advantage: 1.088777408993467e-17
#   mean_baselines: -39.2486457824707
#   mean_log_prob: -1.0650510787963867
#   performance: -90.97761267847913
#   policy_loss: -977.5018559132864
#   total_episodes: 3173
#   total_time: 184.95156908035278
#   total_timesteps: 425722
#   training_episode_length:
#     max: 1000.0
#     mean: 307.65714285714284
#     min: 95.0
#   training_episode_reward:
#     max: 111.52523377432786
#     mean: -90.97761267847913
#     min: -281.80410436564847
#
# === ActorCriticTrainer LunarLander-v2 Iteration 42 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 27.105082187652588
#   evaluate_reward: -85.6866036774743
#   iter_episodes: 37
#   iter_time: 6.511980772018433
#   iter_timesteps: 10250
#   iteration: 42
#   mean_advantage: -1.3777596949494625e-17
#   mean_baselines: -34.92387771606445
#   mean_log_prob: -1.042433738708496
#   performance: -49.42327882735031
#   policy_loss: -1110.112777796248
#   total_episodes: 3210
#   total_time: 191.46354985237122
#   total_timesteps: 435972
#   training_episode_length:
#     max: 1000.0
#     mean: 277.02702702702703
#     min: 115.0
#   training_episode_reward:
#     max: 74.77264227944693
#     mean: -49.42327882735031
#     min: -285.43641254577096
#
# === ActorCriticTrainer LunarLander-v2 Iteration 43 ===
# Training Progress:
#   advantages_std: 1.0000000000000002
#   critic_loss: 28.883630561828614
#   evaluate_reward: -16.231791472927373
#   iter_episodes: 37
#   iter_time: 6.208580732345581
#   iter_timesteps: 10075
#   iteration: 43
#   mean_advantage: -1.2694560043356629e-17
#   mean_baselines: -34.70661163330078
#   mean_log_prob: -0.999347448348999
#   performance: -85.08866026546953
#   policy_loss: -914.9001465296013
#   total_episodes: 3247
#   total_time: 197.6721305847168
#   total_timesteps: 446047
#   training_episode_length:
#     max: 1000.0
#     mean: 272.2972972972973
#     min: 101.0
#   training_episode_reward:
#     max: 76.13412131304021
#     mean: -85.08866026546953
#     min: -315.2903392590889
#
# === ActorCriticTrainer LunarLander-v2 Iteration 44 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 32.91484859466553
#   evaluate_reward: -0.3151546121342449
#   iter_episodes: 34
#   iter_time: 8.153577089309692
#   iter_timesteps: 10102
#   iteration: 44
#   mean_advantage: -3.868526080657841e-18
#   mean_baselines: -32.01024627685547
#   mean_log_prob: -1.0238933563232422
#   performance: -75.822540654107
#   policy_loss: -797.9130586972439
#   total_episodes: 3281
#   total_time: 205.8257076740265
#   total_timesteps: 456149
#   training_episode_length:
#     max: 1000.0
#     mean: 297.11764705882354
#     min: 130.0
#   training_episode_reward:
#     max: 71.96728339757331
#     mean: -75.822540654107
#     min: -257.35397643313314
#
# === ActorCriticTrainer LunarLander-v2 Iteration 45 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 22.773023414611817
#   evaluate_reward: 14.774961651480073
#   iter_episodes: 26
#   iter_time: 8.43493914604187
#   iter_timesteps: 10130
#   iteration: 45
#   mean_advantage: -6.663530098441216e-18
#   mean_baselines: -32.97184371948242
#   mean_log_prob: -1.0565811395645142
#   performance: -51.73490480563805
#   policy_loss: -870.4809982165032
#   total_episodes: 3307
#   total_time: 214.26064682006836
#   total_timesteps: 466279
#   training_episode_length:
#     max: 1000.0
#     mean: 389.61538461538464
#     min: 121.0
#   training_episode_reward:
#     max: 92.91209613149387
#     mean: -51.73490480563805
#     min: -218.09618277001994
#
# === ActorCriticTrainer LunarLander-v2 Iteration 46 ===
# Training Progress:
#   advantages_std: 1.0000000000000002
#   critic_loss: 24.343470935821532
#   evaluate_reward: 12.54629094170458
#   iter_episodes: 33
#   iter_time: 9.48071026802063
#   iter_timesteps: 10785
#   iteration: 46
#   mean_advantage: -5.435306045452783e-18
#   mean_baselines: -27.47528076171875
#   mean_log_prob: -1.0369129180908203
#   performance: -66.54547368322278
#   policy_loss: -1081.0764764451144
#   total_episodes: 3340
#   total_time: 223.741357088089
#   total_timesteps: 477064
#   training_episode_length:
#     max: 1000.0
#     mean: 326.8181818181818
#     min: 114.0
#   training_episode_reward:
#     max: 80.97895476468103
#     mean: -66.54547368322278
#     min: -268.2950412009708
#
# === ActorCriticTrainer LunarLander-v2 Iteration 47 ===
# Training Progress:
#   advantages_std: 0.9999999999999999
#   critic_loss: 22.1838551902771
#   evaluate_reward: -54.20840994616138
#   iter_episodes: 32
#   iter_time: 8.764810562133789
#   iter_timesteps: 10142
#   iteration: 47
#   mean_advantage: 2.0842680328202506e-17
#   mean_baselines: -26.387121200561523
#   mean_log_prob: -1.036598801612854
#   performance: -30.241075651096963
#   policy_loss: -1240.591283327576
#   total_episodes: 3372
#   total_time: 232.50616765022278
#   total_timesteps: 487206
#   training_episode_length:
#     max: 1000.0
#     mean: 316.9375
#     min: 133.0
#   training_episode_reward:
#     max: 138.7911127225099
#     mean: -30.241075651096963
#     min: -259.91281939551845
#
# === ActorCriticTrainer LunarLander-v2 Iteration 48 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 24.150118408203124
#   evaluate_reward: 20.988121965519834
#   iter_episodes: 32
#   iter_time: 6.895047664642334
#   iter_timesteps: 10036
#   iteration: 48
#   mean_advantage: -4.778959213213109e-18
#   mean_baselines: -26.496294021606445
#   mean_log_prob: -1.0462002754211426
#   performance: -25.108314654843692
#   policy_loss: -1059.1223562131695
#   total_episodes: 3404
#   total_time: 239.4012153148651
#   total_timesteps: 497242
#   training_episode_length:
#     max: 1000.0
#     mean: 313.625
#     min: 128.0
#   training_episode_reward:
#     max: 131.439040031966
#     mean: -25.108314654843692
#     min: -241.31474129175655
#
# === ActorCriticTrainer LunarLander-v2 Iteration 49 ===
# Training Progress:
#   advantages_std: 1.0000000000000002
#   critic_loss: 21.054532642364503
#   evaluate_reward: -5.568314002051162
#   iter_episodes: 30
#   iter_time: 8.513242721557617
#   iter_timesteps: 10014
#   iteration: 49
#   mean_advantage: -2.4834227832637813e-18
#   mean_baselines: -26.85768699645996
#   mean_log_prob: -1.035805583000183
#   performance: -21.01446974263072
#   policy_loss: -1290.7392363212152
#   total_episodes: 3434
#   total_time: 247.91445803642273
#   total_timesteps: 507256
#   training_episode_length:
#     max: 1000.0
#     mean: 333.8
#     min: 124.0
#   training_episode_reward:
#     max: 113.56173744343063
#     mean: -21.01446974263072
#     min: -205.1076982933415
#
# === ActorCriticTrainer LunarLander-v2 Iteration 50 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 11.874744939804078
#   evaluate_reward: -8.156945636253734
#   iter_episodes: 22
#   iter_time: 9.210945129394531
#   iter_timesteps: 10082
#   iteration: 50
#   mean_advantage: -5.28572755227212e-18
#   mean_baselines: -20.688064575195312
#   mean_log_prob: -1.0815969705581665
#   performance: -4.157553639625672
#   policy_loss: -1017.3845959579216
#   total_episodes: 3456
#   total_time: 257.12540316581726
#   total_timesteps: 517338
#   training_episode_length:
#     max: 1000.0
#     mean: 458.27272727272725
#     min: 138.0
#   training_episode_reward:
#     max: 100.42341327723743
#     mean: -4.157553639625672
#     min: -200.65713408791453
#
# === ActorCriticTrainer LunarLander-v2 Iteration 51 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 13.677779369354248
#   evaluate_reward: -28.004419627955002
#   iter_episodes: 30
#   iter_time: 7.894763708114624
#   iter_timesteps: 10171
#   iteration: 51
#   mean_advantage: 7.859213231050169e-18
#   mean_baselines: -14.809809684753418
#   mean_log_prob: -1.0330119132995605
#   performance: 3.8466978100481697
#   policy_loss: -1343.6197285759617
#   total_episodes: 3486
#   total_time: 265.0201668739319
#   total_timesteps: 527509
#   training_episode_length:
#     max: 1000.0
#     mean: 339.03333333333336
#     min: 92.0
#   training_episode_reward:
#     max: 113.46825083398369
#     mean: 3.8466978100481697
#     min: -116.98586508623794
#
# === ActorCriticTrainer LunarLander-v2 Iteration 52 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 12.077988481521606
#   evaluate_reward: -29.30491705880123
#   iter_episodes: 25
#   iter_time: 8.649051427841187
#   iter_timesteps: 10546
#   iteration: 52
#   mean_advantage: -8.253507029263444e-18
#   mean_baselines: -14.956262588500977
#   mean_log_prob: -1.034397840499878
#   performance: 8.230435965691834
#   policy_loss: -1325.3430242216475
#   total_episodes: 3511
#   total_time: 273.66921830177307
#   total_timesteps: 538055
#   training_episode_length:
#     max: 1000.0
#     mean: 421.84
#     min: 99.0
#   training_episode_reward:
#     max: 106.87885287322851
#     mean: 8.230435965691834
#     min: -79.72520238268267
#
# === ActorCriticTrainer LunarLander-v2 Iteration 53 ===
# Training Progress:
#   advantages_std: 0.9999999999999999
#   critic_loss: 13.885227823257447
#   evaluate_reward: -2.831773454703594
#   iter_episodes: 28
#   iter_time: 6.930131673812866
#   iter_timesteps: 10153
#   iteration: 53
#   mean_advantage: 1.1372322915494561e-17
#   mean_baselines: -13.606390953063965
#   mean_log_prob: -1.0005860328674316
#   performance: 4.475130084972056
#   policy_loss: -1324.3013602889478
#   total_episodes: 3539
#   total_time: 280.59934997558594
#   total_timesteps: 548208
#   training_episode_length:
#     max: 1000.0
#     mean: 362.60714285714283
#     min: 111.0
#   training_episode_reward:
#     max: 133.3694257102181
#     mean: 4.475130084972056
#     min: -96.86876779582431
#
# === ActorCriticTrainer LunarLander-v2 Iteration 54 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 11.121784772872925
#   evaluate_reward: 12.680863126518895
#   iter_episodes: 20
#   iter_time: 9.938113689422607
#   iter_timesteps: 10104
#   iteration: 54
#   mean_advantage: 2.0613404534805955e-17
#   mean_baselines: -14.900811195373535
#   mean_log_prob: -1.037207841873169
#   performance: 16.24063311212613
#   policy_loss: -941.0713366826451
#   total_episodes: 3559
#   total_time: 290.53746366500854
#   total_timesteps: 558312
#   training_episode_length:
#     max: 1000.0
#     mean: 505.2
#     min: 128.0
#   training_episode_reward:
#     max: 109.01498053168139
#     mean: 16.24063311212613
#     min: -112.52221010987071
#
# === ActorCriticTrainer LunarLander-v2 Iteration 55 ===
# Training Progress:
#   advantages_std: 1.0000000000000002
#   critic_loss: 11.610809230804444
#   evaluate_reward: -82.55459019269988
#   iter_episodes: 22
#   iter_time: 10.938628435134888
#   iter_timesteps: 10720
#   iteration: 55
#   mean_advantage: 6.628197161941233e-18
#   mean_baselines: -12.254371643066406
#   mean_log_prob: -1.0193707942962646
#   performance: 8.260490916737165
#   policy_loss: -1214.24245683976
#   total_episodes: 3581
#   total_time: 301.47609210014343
#   total_timesteps: 569032
#   training_episode_length:
#     max: 1000.0
#     mean: 487.27272727272725
#     min: 156.0
#   training_episode_reward:
#     max: 126.82172150913217
#     mean: 8.260490916737165
#     min: -105.55293275277063
#
# === ActorCriticTrainer LunarLander-v2 Iteration 56 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 11.4419863986969
#   evaluate_reward: -4.138815294305137
#   iter_episodes: 24
#   iter_time: 9.753533124923706
#   iter_timesteps: 10646
#   iteration: 56
#   mean_advantage: -1.8020527771484787e-17
#   mean_baselines: -8.493780136108398
#   mean_log_prob: -0.9915300011634827
#   performance: 4.450151221582655
#   policy_loss: -1330.8109395053268
#   total_episodes: 3605
#   total_time: 311.22962522506714
#   total_timesteps: 579678
#   training_episode_length:
#     max: 1000.0
#     mean: 443.5833333333333
#     min: 113.0
#   training_episode_reward:
#     max: 99.24185567149593
#     mean: 4.450151221582655
#     min: -71.87957582847555
#
# === ActorCriticTrainer LunarLander-v2 Iteration 57 ===
# Training Progress:
#   advantages_std: 0.9999999999999998
#   critic_loss: 11.319429502487182
#   evaluate_reward: 48.6064722826618
#   iter_episodes: 19
#   iter_time: 11.153325319290161
#   iter_timesteps: 10868
#   iteration: 57
#   mean_advantage: -7.845521557895844e-18
#   mean_baselines: -9.370044708251953
#   mean_log_prob: -0.9622597694396973
#   performance: 17.564277930549917
#   policy_loss: -1193.7270221108317
#   total_episodes: 3624
#   total_time: 322.3829505443573
#   total_timesteps: 590546
#   training_episode_length:
#     max: 1000.0
#     mean: 572.0
#     min: 174.0
#   training_episode_reward:
#     max: 110.30224512363175
#     mean: 17.564277930549917
#     min: -82.19318634231603
#
# === ActorCriticTrainer LunarLander-v2 Iteration 58 ===
# Training Progress:
#   advantages_std: 0.9999999999999999
#   critic_loss: 12.585272455215454
#   evaluate_reward: -45.519341098233284
#   iter_episodes: 19
#   iter_time: 10.907304048538208
#   iter_timesteps: 10214
#   iteration: 58
#   mean_advantage: -1.120386119671412e-17
#   mean_baselines: -7.536290645599365
#   mean_log_prob: -0.9375560283660889
#   performance: -53.98569586628945
#   policy_loss: -673.7761936730726
#   total_episodes: 3643
#   total_time: 333.2902545928955
#   total_timesteps: 600760
#   training_episode_length:
#     max: 1000.0
#     mean: 537.578947368421
#     min: 179.0
#   training_episode_reward:
#     max: 85.94255752181078
#     mean: -53.98569586628945
#     min: -227.74441521309785
#
# === ActorCriticTrainer LunarLander-v2 Iteration 59 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 12.230457677841187
#   evaluate_reward: -55.58931704987905
#   iter_episodes: 15
#   iter_time: 13.736871242523193
#   iter_timesteps: 10462
#   iteration: 59
#   mean_advantage: -4.796604923824993e-18
#   mean_baselines: -8.866004943847656
#   mean_log_prob: -0.9391699433326721
#   performance: -53.90956920289879
#   policy_loss: -202.4606911164474
#   total_episodes: 3658
#   total_time: 347.0271258354187
#   total_timesteps: 611222
#   training_episode_length:
#     max: 1000.0
#     mean: 697.4666666666667
#     min: 216.0
#   training_episode_reward:
#     max: 146.30450401118475
#     mean: -53.90956920289879
#     min: -337.1168367038436
#
# === ActorCriticTrainer LunarLander-v2 Iteration 60 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 9.989766178131104
#   evaluate_reward: -12.771700176854557
#   iter_episodes: 15
#   iter_time: 11.204205751419067
#   iter_timesteps: 10030
#   iteration: 60
#   mean_advantage: -5.755892051895129e-18
#   mean_baselines: -5.108870506286621
#   mean_log_prob: -0.9639400243759155
#   performance: -75.49758895849733
#   policy_loss: -501.6443025980666
#   total_episodes: 3673
#   total_time: 358.23133158683777
#   total_timesteps: 621252
#   training_episode_length:
#     max: 1000.0
#     mean: 668.6666666666666
#     min: 269.0
#   training_episode_reward:
#     max: 132.88313657041977
#     mean: -75.49758895849733
#     min: -375.20658312313265
#
# === ActorCriticTrainer LunarLander-v2 Iteration 61 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 7.778877191543579
#   evaluate_reward: 10.398229385889508
#   iter_episodes: 12
#   iter_time: 12.565814733505249
#   iter_timesteps: 10306
#   iteration: 61
#   mean_advantage: -9.738420476044455e-18
#   mean_baselines: -5.483832359313965
#   mean_log_prob: -0.9534273743629456
#   performance: -48.084706545437335
#   policy_loss: -445.69540027177334
#   total_episodes: 3685
#   total_time: 370.797146320343
#   total_timesteps: 631558
#   training_episode_length:
#     max: 1000.0
#     mean: 858.8333333333334
#     min: 354.0
#   training_episode_reward:
#     max: 49.80947143512256
#     mean: -48.084706545437335
#     min: -181.4985416525181
#
# === ActorCriticTrainer LunarLander-v2 Iteration 62 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 8.63395094871521
#   evaluate_reward: -76.75382367455332
#   iter_episodes: 14
#   iter_time: 12.675516128540039
#   iter_timesteps: 10113
#   iteration: 62
#   mean_advantage: -1.6511177979197424e-17
#   mean_baselines: -8.850578308105469
#   mean_log_prob: -0.9601811766624451
#   performance: 2.64536974899215
#   policy_loss: -807.0749190365035
#   total_episodes: 3699
#   total_time: 383.47266244888306
#   total_timesteps: 641671
#   training_episode_length:
#     max: 1000.0
#     mean: 722.3571428571429
#     min: 283.0
#   training_episode_reward:
#     max: 117.13998791176172
#     mean: 2.64536974899215
#     min: -92.60631876794022
#
# === ActorCriticTrainer LunarLander-v2 Iteration 63 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 8.323157062530518
#   evaluate_reward: 7.763996004116083
#   iter_episodes: 15
#   iter_time: 12.00960636138916
#   iter_timesteps: 10072
#   iteration: 63
#   mean_advantage: -8.81829249106558e-18
#   mean_baselines: -4.869325160980225
#   mean_log_prob: -0.9290653467178345
#   performance: -17.49478405570521
#   policy_loss: -1118.901505084978
#   total_episodes: 3714
#   total_time: 395.4822688102722
#   total_timesteps: 651743
#   training_episode_length:
#     max: 1000.0
#     mean: 671.4666666666667
#     min: 148.0
#   training_episode_reward:
#     max: 113.10700389565488
#     mean: -17.49478405570521
#     min: -147.3154913580369
#
# === ActorCriticTrainer LunarLander-v2 Iteration 64 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 7.593078675270081
#   evaluate_reward: 39.183937805281765
#   iter_episodes: 12
#   iter_time: 14.579116582870483
#   iter_timesteps: 10659
#   iteration: 64
#   mean_advantage: -1.1665726499485648e-17
#   mean_baselines: -9.764707565307617
#   mean_log_prob: -0.9590901732444763
#   performance: 42.88155597796589
#   policy_loss: -994.5773335986069
#   total_episodes: 3726
#   total_time: 410.0613853931427
#   total_timesteps: 662402
#   training_episode_length:
#     max: 1000.0
#     mean: 888.25
#     min: 316.0
#   training_episode_reward:
#     max: 151.7548542853473
#     mean: 42.88155597796589
#     min: -130.55200892153377
#
# === ActorCriticTrainer LunarLander-v2 Iteration 65 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 5.132057256698609
#   evaluate_reward: -0.22864095422761038
#   iter_episodes: 12
#   iter_time: 14.728374242782593
#   iter_timesteps: 10111
#   iteration: 65
#   mean_advantage: -7.027422962714867e-19
#   mean_baselines: -6.582099437713623
#   mean_log_prob: -0.9738394021987915
#   performance: 47.83076694307564
#   policy_loss: -1147.514682390821
#   total_episodes: 3738
#   total_time: 424.7897596359253
#   total_timesteps: 672513
#   training_episode_length:
#     max: 1000.0
#     mean: 842.5833333333334
#     min: 221.0
#   training_episode_reward:
# ...
#     min: -47.395815673189404
#
# === ActorCriticTrainer LunarLander-v2 Iteration 78 ===
# Training Progress:
#   advantages_std: 0.9999999999999999
#   critic_loss: 1.874982898235321
#   evaluate_reward: 101.28338866844186
#   iter_episodes: 11
#   iter_time: 18.34726119041443
#   iter_timesteps: 11000
#   iteration: 78
#   mean_advantage: -1.2757471846601798e-17
#   mean_baselines: -0.6770021319389343
#   mean_log_prob: -0.9983704090118408
#   performance: 81.69799583069842
#   policy_loss: -1768.5230065278693
#   total_episodes: 3908
#   total_time: 608.5115478038788
#   total_timesteps: 809580
#   training_episode_length:
#     max: 1000.0
#     mean: 1000.0
#     min: 1000.0
#   training_episode_reward:
#     max: 125.11535850796088
#     mean: 81.69799583069842
#     min: 57.63135577747233
#
# === ActorCriticTrainer LunarLander-v2 Iteration 79 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 4.372149481773376
#   evaluate_reward: 64.94747521449708
#   iter_episodes: 11
#   iter_time: 15.98615550994873
#   iter_timesteps: 10107
#   iteration: 79
#   mean_advantage: 3.954489847284618e-18
#   mean_baselines: 1.0228512287139893
#   mean_log_prob: -1.006990671157837
#   performance: 18.99604222369926
#   policy_loss: -1061.5988893352383
#   total_episodes: 3919
#   total_time: 624.4977033138275
#   total_timesteps: 819687
#   training_episode_length:
#     max: 1000.0
#     mean: 918.8181818181819
#     min: 538.0
#   training_episode_reward:
#     max: 152.46596845399515
#     mean: 18.99604222369926
#     min: -134.29339485450498
#
# === ActorCriticTrainer LunarLander-v2 Iteration 80 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 3.3403669881820677
#   evaluate_reward: 35.56642999057224
#   iter_episodes: 12
#   iter_time: 15.153033971786499
#   iter_timesteps: 10557
#   iteration: 80
#   mean_advantage: -1.8929633838451093e-18
#   mean_baselines: -1.239442229270935
#   mean_log_prob: -1.0069228410720825
#   performance: 50.4168425487882
#   policy_loss: -1468.65854692256
#   total_episodes: 3931
#   total_time: 639.650737285614
#   total_timesteps: 830244
#   training_episode_length:
#     max: 1000.0
#     mean: 879.75
#     min: 254.0
#   training_episode_reward:
#     max: 105.28201288416088
#     mean: 50.4168425487882
#     min: -98.74269274468762
#
# === ActorCriticTrainer LunarLander-v2 Iteration 81 ===
# Training Progress:
#   advantages_std: 0.9999999999999999
#   critic_loss: 3.6149894165992738
#   evaluate_reward: -25.830999059545768
#   iter_episodes: 11
#   iter_time: 13.639516830444336
#   iter_timesteps: 10417
#   iteration: 81
#   mean_advantage: -3.410495995776616e-19
#   mean_baselines: 0.052795685827732086
#   mean_log_prob: -0.9551337361335754
#   performance: 48.8728706248321
#   policy_loss: -1215.6850551154619
#   total_episodes: 3942
#   total_time: 653.2902541160583
#   total_timesteps: 840661
#   training_episode_length:
#     max: 1000.0
#     mean: 947.0
#     min: 674.0
#   training_episode_reward:
#     max: 154.56490282454843
#     mean: 48.8728706248321
#     min: -111.4247544423976
#
# === ActorCriticTrainer LunarLander-v2 Iteration 82 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 6.722594337463379
#   evaluate_reward: 75.52282755188749
#   iter_episodes: 13
#   iter_time: 15.067176580429077
#   iter_timesteps: 10973
#   iteration: 82
#   mean_advantage: 7.426443999588672e-18
#   mean_baselines: 0.6820635199546814
#   mean_log_prob: -0.9707704186439514
#   performance: -0.9457322407646941
#   policy_loss: -660.1519680177115
#   total_episodes: 3955
#   total_time: 668.3574306964874
#   total_timesteps: 851634
#   training_episode_length:
#     max: 1000.0
#     mean: 844.0769230769231
#     min: 225.0
#   training_episode_reward:
#     max: 88.9610020897125
#     mean: -0.9457322407646941
#     min: -104.50982831090155
#
# === ActorCriticTrainer LunarLander-v2 Iteration 83 ===
# Training Progress:
#   advantages_std: 0.9999999999999998
#   critic_loss: 3.38206561088562
#   evaluate_reward: 36.49811632560291
#   iter_episodes: 11
#   iter_time: 16.93451762199402
#   iter_timesteps: 10829
#   iteration: 83
#   mean_advantage: 9.104054352822413e-18
#   mean_baselines: 0.33754926919937134
#   mean_log_prob: -0.9800979495048523
#   performance: 83.91715291449874
#   policy_loss: -1540.8312928290952
#   total_episodes: 3966
#   total_time: 685.2919483184814
#   total_timesteps: 862463
#   training_episode_length:
#     max: 1000.0
#     mean: 984.4545454545455
#     min: 829.0
#   training_episode_reward:
#     max: 133.4518006326313
#     mean: 83.91715291449874
#     min: 26.020352350720614
#
# === ActorCriticTrainer LunarLander-v2 Iteration 84 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 2.56665739774704
#   evaluate_reward: 119.35834067049234
#   iter_episodes: 11
#   iter_time: 17.342473030090332
#   iter_timesteps: 11000
#   iteration: 84
#   mean_advantage: 5.652044489000797e-19
#   mean_baselines: 1.1126251220703125
#   mean_log_prob: -0.9957387447357178
#   performance: 84.91653359374585
#   policy_loss: -1119.8545621803537
#   total_episodes: 3977
#   total_time: 702.6344213485718
#   total_timesteps: 873463
#   training_episode_length:
#     max: 1000.0
#     mean: 1000.0
#     min: 1000.0
#   training_episode_reward:
#     max: 158.158324725302
#     mean: 84.91653359374585
#     min: -32.52794315422215
#
# === ActorCriticTrainer LunarLander-v2 Iteration 85 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 2.682304039001465
#   evaluate_reward: 88.62489059937977
#   iter_episodes: 11
#   iter_time: 15.33235764503479
#   iter_timesteps: 10615
#   iteration: 85
#   mean_advantage: -1.0207985605597294e-17
#   mean_baselines: 2.150205612182617
#   mean_log_prob: -0.9253072738647461
#   performance: 90.2929004751221
#   policy_loss: -1305.3007082268864
#   total_episodes: 3988
#   total_time: 717.9667789936066
#   total_timesteps: 884078
#   training_episode_length:
#     max: 1000.0
#     mean: 965.0
#     min: 615.0
#   training_episode_reward:
#     max: 134.45156561600595
#     mean: 90.2929004751221
#     min: -22.203347612426484
#
# === ActorCriticTrainer LunarLander-v2 Iteration 86 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 2.510546827316284
#   evaluate_reward: 62.86715061957849
#   iter_episodes: 11
#   iter_time: 17.525021076202393
#   iter_timesteps: 10894
#   iteration: 86
#   mean_advantage: 6.11468528341375e-19
#   mean_baselines: 2.320441246032715
#   mean_log_prob: -0.919532835483551
#   performance: 101.35589359019882
#   policy_loss: -1321.0818310883678
#   total_episodes: 3999
#   total_time: 735.491800069809
#   total_timesteps: 894972
#   training_episode_length:
#     max: 1000.0
#     mean: 990.3636363636364
#     min: 894.0
#   training_episode_reward:
#     max: 191.54326502483408
#     mean: 101.35589359019882
#     min: 69.08221347642021
#
# === ActorCriticTrainer LunarLander-v2 Iteration 87 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 4.127678611278534
#   evaluate_reward: 33.45119184073603
#   iter_episodes: 11
#   iter_time: 16.386734008789062
#   iter_timesteps: 10076
#   iteration: 87
#   mean_advantage: 5.6635037183141176e-18
#   mean_baselines: 4.503096103668213
#   mean_log_prob: -0.908370316028595
#   performance: 69.55342303095375
#   policy_loss: -779.295460250109
#   total_episodes: 4010
#   total_time: 751.878534078598
#   total_timesteps: 905048
#   training_episode_length:
#     max: 1000.0
#     mean: 916.0
#     min: 484.0
#   training_episode_reward:
#     max: 137.5513218951027
#     mean: 69.55342303095375
#     min: -48.14204246547247
#
# === ActorCriticTrainer LunarLander-v2 Iteration 88 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 4.7975088262557986
#   evaluate_reward: 43.50970068363587
#   iter_episodes: 12
#   iter_time: 12.168655633926392
#   iter_timesteps: 10400
#   iteration: 88
#   mean_advantage: 9.564998366001348e-18
#   mean_baselines: 4.277421474456787
#   mean_log_prob: -0.8824303150177002
#   performance: 95.82985778809227
#   policy_loss: -926.156436523057
#   total_episodes: 4022
#   total_time: 764.0471897125244
#   total_timesteps: 915448
#   training_episode_length:
#     max: 1000.0
#     mean: 866.6666666666666
#     min: 334.0
#   training_episode_reward:
#     max: 223.83168716435182
#     mean: 95.82985778809227
#     min: -39.61153360663276
#
# === ActorCriticTrainer LunarLander-v2 Iteration 89 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 9.756389341354371
#   evaluate_reward: 43.49674179317655
#   iter_episodes: 14
#   iter_time: 12.60778522491455
#   iter_timesteps: 10626
#   iteration: 89
#   mean_advantage: 1.8702232392989178e-18
#   mean_baselines: 5.92717170715332
#   mean_log_prob: -0.8592677712440491
#   performance: 126.71917417592624
#   policy_loss: -1075.4103971494692
#   total_episodes: 4036
#   total_time: 776.654974937439
#   total_timesteps: 926074
#   training_episode_length:
#     max: 1000.0
#     mean: 759.0
#     min: 460.0
#   training_episode_reward:
#     max: 263.14412926165755
#     mean: 126.71917417592624
#     min: -62.61326046147044
#
# === ActorCriticTrainer LunarLander-v2 Iteration 90 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 8.19256543636322
#   evaluate_reward: 126.55052893437168
#   iter_episodes: 13
#   iter_time: 11.055813312530518
#   iter_timesteps: 10034
#   iteration: 90
#   mean_advantage: -9.205755994500002e-18
#   mean_baselines: 4.215314865112305
#   mean_log_prob: -0.8387182950973511
#   performance: 95.0221438694239
#   policy_loss: -910.082512917948
#   total_episodes: 4049
#   total_time: 787.7107882499695
#   total_timesteps: 936108
#   training_episode_length:
#     max: 1000.0
#     mean: 771.8461538461538
#     min: 374.0
#   training_episode_reward:
#     max: 258.11674860167057
#     mean: 95.0221438694239
#     min: -55.96953335101581
#
# === ActorCriticTrainer LunarLander-v2 Iteration 91 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 11.750762062072754
#   evaluate_reward: 132.80309644360298
#   iter_episodes: 15
#   iter_time: 11.523480653762817
#   iter_timesteps: 10220
#   iteration: 91
#   mean_advantage: 1.7381182381607146e-18
#   mean_baselines: 6.581363677978516
#   mean_log_prob: -0.8711596131324768
#   performance: 103.76579917023714
#   policy_loss: -916.6420206732664
#   total_episodes: 4064
#   total_time: 799.2342689037323
#   total_timesteps: 946328
#   training_episode_length:
#     max: 1000.0
#     mean: 681.3333333333334
#     min: 374.0
#   training_episode_reward:
#     max: 238.50527053019434
#     mean: 103.76579917023714
#     min: -97.45088958007725
#
# === ActorCriticTrainer LunarLander-v2 Iteration 92 ===
# Training Progress:
#   advantages_std: 0.9999999999999998
#   critic_loss: 17.009498805999755
#   evaluate_reward: 130.4173075525154
#   iter_episodes: 16
#   iter_time: 11.720688819885254
#   iter_timesteps: 10622
#   iteration: 92
#   mean_advantage: 1.6723374500096502e-18
#   mean_baselines: 4.310075759887695
#   mean_log_prob: -0.90916508436203
#   performance: 154.59067642005246
#   policy_loss: -911.0899236205755
#   total_episodes: 4080
#   total_time: 810.9549577236176
#   total_timesteps: 956950
#   training_episode_length:
#     max: 1000.0
#     mean: 663.875
#     min: 442.0
#   training_episode_reward:
#     max: 247.09638146620827
#     mean: 154.59067642005246
#     min: -64.74055678057184
#
# === ActorCriticTrainer LunarLander-v2 Iteration 93 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 12.82660789489746
#   evaluate_reward: 88.31879335946503
#   iter_episodes: 14
#   iter_time: 11.794576168060303
#   iter_timesteps: 10044
#   iteration: 93
#   mean_advantage: 1.945432619813098e-18
#   mean_baselines: 4.716475009918213
#   mean_log_prob: -0.9102951884269714
#   performance: 146.77555491417044
#   policy_loss: -909.7595747490383
#   total_episodes: 4094
#   total_time: 822.7495338916779
#   total_timesteps: 966994
#   training_episode_length:
#     max: 1000.0
#     mean: 717.4285714285714
#     min: 498.0
#   training_episode_reward:
#     max: 226.24523690602678
#     mean: 146.77555491417044
#     min: -65.4920360781955
#
# === ActorCriticTrainer LunarLander-v2 Iteration 94 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 12.05910527229309
#   evaluate_reward: 193.37114931411242
#   iter_episodes: 14
#   iter_time: 13.029747009277344
#   iter_timesteps: 10169
#   iteration: 94
#   mean_advantage: -1.0131644870214822e-17
#   mean_baselines: 9.259611129760742
#   mean_log_prob: -0.9309034943580627
#   performance: 171.63259002202696
#   policy_loss: -639.6716080596375
#   total_episodes: 4108
#   total_time: 835.7792809009552
#   total_timesteps: 977163
#   training_episode_length:
#     max: 918.0
#     mean: 726.3571428571429
#     min: 410.0
#   training_episode_reward:
#     max: 236.949558641035
#     mean: 171.63259002202696
#     min: -56.93243853837462
#
# === ActorCriticTrainer LunarLander-v2 Iteration 95 ===
# Training Progress:
#   advantages_std: 0.9999999999999999
#   critic_loss: 10.791547956466674
#   evaluate_reward: 175.46501798022254
#   iter_episodes: 14
#   iter_time: 14.000727415084839
#   iter_timesteps: 10226
#   iteration: 95
#   mean_advantage: 1.0422590491298163e-18
#   mean_baselines: 8.68985652923584
#   mean_log_prob: -0.9598990678787231
#   performance: 137.75855694694454
#   policy_loss: -783.4471301773355
#   total_episodes: 4122
#   total_time: 849.78000831604
#   total_timesteps: 987389
#   training_episode_length:
#     max: 892.0
#     mean: 730.4285714285714
#     min: 605.0
#   training_episode_reward:
#     max: 219.61719430153414
#     mean: 137.75855694694454
#     min: -41.72980541788176
#
# === ActorCriticTrainer LunarLander-v2 Iteration 96 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 11.394788608551025
#   evaluate_reward: 147.25863544774893
#   iter_episodes: 14
#   iter_time: 12.21952486038208
#   iter_timesteps: 10203
#   iteration: 96
#   mean_advantage: -2.681161945189048e-17
#   mean_baselines: 8.955570220947266
#   mean_log_prob: -0.9587914943695068
#   performance: 134.77514465698604
#   policy_loss: -516.1571506397493
#   total_episodes: 4136
#   total_time: 861.9995331764221
#   total_timesteps: 997592
#   training_episode_length:
#     max: 974.0
#     mean: 728.7857142857143
#     min: 540.0
#   training_episode_reward:
#     max: 226.04164151729034
#     mean: 134.77514465698604
#     min: -66.0474892108958
#
# === ActorCriticTrainer LunarLander-v2 Iteration 97 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 10.433787050247192
#   evaluate_reward: 33.37802757483266
#   iter_episodes: 14
#   iter_time: 12.693584680557251
#   iter_timesteps: 10655
#   iteration: 97
#   mean_advantage: -2.0339327490082643e-17
#   mean_baselines: 11.581258773803711
#   mean_log_prob: -0.9233396053314209
#   performance: 153.42654364721466
#   policy_loss: -704.7687202972497
#   total_episodes: 4150
#   total_time: 874.6931178569794
#   total_timesteps: 1008247
#   training_episode_length:
#     max: 1000.0
#     mean: 761.0714285714286
#     min: 474.0
#   training_episode_reward:
#     max: 250.0681690786041
#     mean: 153.42654364721466
#     min: -73.65138538372322
#
# === ActorCriticTrainer LunarLander-v2 Iteration 98 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 10.474645862579345
#   evaluate_reward: 172.6146456222521
#   iter_episodes: 15
#   iter_time: 12.013132333755493
#   iter_timesteps: 10448
#   iteration: 98
#   mean_advantage: -7.820866635950567e-18
#   mean_baselines: 13.084615707397461
#   mean_log_prob: -0.9310399293899536
#   performance: 174.73456026192326
#   policy_loss: -1002.4272352607961
#   total_episodes: 4165
#   total_time: 886.7062501907349
#   total_timesteps: 1018695
#   training_episode_length:
#     max: 871.0
#     mean: 696.5333333333333
#     min: 587.0
#   training_episode_reward:
#     max: 263.17769510188054
#     mean: 174.73456026192326
#     min: -100.21600240558435
#
# === ActorCriticTrainer LunarLander-v2 Iteration 99 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 11.32260721206665
#   evaluate_reward: 208.6250582737137
#   iter_episodes: 15
#   iter_time: 11.32494831085205
#   iter_timesteps: 10283
#   iteration: 99
#   mean_advantage: -7.082624760810101e-18
#   mean_baselines: 11.767306327819824
#   mean_log_prob: -0.9331905841827393
#   performance: 138.9059960105995
#   policy_loss: -804.6027285371589
#   total_episodes: 4180
#   total_time: 898.0311985015869
#   total_timesteps: 1028978
#   training_episode_length:
#     max: 1000.0
#     mean: 685.5333333333333
#     min: 526.0
#   training_episode_reward:
#     max: 249.48628427737003
#     mean: 138.9059960105995
#     min: -92.12635241854011
#
# In 99 iteration, cupretty_printrrent mean episode reward 208.625 is greater than reward threshold 200. Congratulation! Now we exit the training process.

# %%
# Run this cell without modification

# Plot the result to diagnose potential problem.
sns.lineplot(
    x="total_timesteps", y="performance", data=ac_result_lander
).set_title("Episode Reward in LunarLander-v2")
# Out:
# Text(0.5, 1.0, 'Episode Reward in LunarLander-v2')

# %%
# Run this cell without modification

# You should see a pop up window which display the movement of the cart and pole.
print("Average episode reward for your Actor-critic agent in LunarLander-v2: ",
      ac_trainer_lander.evaluate(1, render=True))
print("One small step for agent, one giant leap for mankind.")
# Out:
# Average episode reward for your Actor-critic agent in LunarLander-v2:  188.30675844003144
# One small step for agent, one giant leap for mankind.

# %% [markdown]
# ### Section 4.3: Even harder -- train Pong agents
#
# (5 / 100 points)

# %%
# Run this cell without modification
e = gym.make("PongDeterministic-v4"); e.reset()
frames = []
for _ in range(1000):
    frames.append(e.render("rgb_array"))
    if e.step(e.action_space.sample())[2]: break
e.close();animate(frames);del e

# %% [markdown]
# In this section, we will train agents to play Pong game in Atari environment. The agent control the bat on the right with up or down action to make it hit the table tennis ball to left side. The agent need to beat a rule-based AI.
#
# The observation of the environment `PongDeterministic-v4` is an image of 210 X 160 X 3 pixels. We compress the image and flatten it to be a vector with 6400 elements. To do this, we provide you a wrapper class which wrap the actor-critic trainer to fit this environment. You need to implement the save and restore functions.
#
# In the assignment 4, we will trained state of the art Pong agents with various algorithms. Your agents will battle with other AI. Let's get familiar with Pong by finishing this section!

# %%
# Run this cell without modification

def process_img(img):
    """In this function, we process the raw image array into a flat vector.
    We assume the img has four dimension, with shape in [Batch size, Width, Height, Channel].
    Therefore the raw image is a 4D matrix containing the intensity of colors.
    """
    assert img.shape[-3:] == (210, 160, 3), img.shape
    
    # Add extra axis if input is a single image and make it looks like a batch.
    single_img = False
    if img.ndim == 3:
        img = img[None, ...]
        single_img = True
        
    # Crop the image
    img = img[:, 35:195]
    
    # Shrink the image size by taking only 1/4 of the pixel
    img = img[:, ::2, ::2, 0]
    
    # Erase background
    img[img == 144] = 0
    img[img == 109] = 0
    
    # Paint everything (paddles, ball) to 1
    img[img != 0 ] = 1
    
    # Flatten image to vector
    img = img.astype(np.float).reshape(-1, 6400)
    
    # Reverse single image
    if single_img:
        img = img[0, ...]
    return img

# %%
# Solve the TODOs and remove `pass`

def pong_wrapper(trainer):
    assert inspect.isclass(trainer)
    
    class WrappedTrainer(trainer):
        def __init__(self, *a, **k):
            super().__init__(*a, **k)
            self.obs_dim = 6400
            self.build_model()
            assert "Pong" in self.config["env_name"]
            
        def compute_action(self, obs):
            obs = process_img(obs)
            return super().compute_action(obs)
            
        def process_samples(self, samples):
            samples["obs"] = [process_img(traj_obs) for traj_obs in samples["obs"]]
            return super().process_samples(samples)
        
        def train(self):
            ret = super().train()
            if self.iteration % self.config["evaluate_interval"] == 0:
                self.save("iter{}".format(self.iteration))
                print("Finished {} iterations training. "
                      "Checkpoint is saved in checkpoints directory.".format(self.iteration))
            return ret
        
        def save(self, surfix="checkpoint"):
            import pickle
            import os
            os.makedirs("checkpoints", exist_ok=True)
            policy_file_name = "checkpoints/pong-agent-{}-policy.pkl".format(surfix)
            with open(policy_file_name, "wb") as f:
                # [TODO] Use function of pickle package and torch model to save 
                # the parameters of self.policy to file "f".
                # Hint: a function called state_dict of torch model may help.
                torch.save(self.baseline.state_dict(), f)
            
            baseline_file_name = "checkpoints/pong-agent-{}-baseline.pkl".format(surfix)
            with open(baseline_file_name, "wb") as f:
                # [TODO] Use function of pickle package and torch model to save 
                # the parameters of self.baseline to file "f".
                torch.save(self.baseline.state_dict(), f)
                    
        def restore(self, surfix="checkpoint"):
            import pickle
            policy_file_name = "checkpoints/pong-agent-{}-policy.pkl".format(surfix)
            with open(policy_file_name, "rb") as f:
                # [TODO] Use function of pickle package and torch model to restore 
                # the parameters of self.policy from file "f".
                # Hint: a function called load_state_dict of torch model may help.
                self.policy.load_state_dict(torch.load(f))
                
            baseline_file_name = "checkpoints/pong-agent-{}-baseline.pkl".format(surfix)
            with open(baseline_file_name, "rb") as f:
                # [TODO] Use function of pickle package and torch model to restore 
                # the parameters of self.baseline from file "f".
                self.policy.load_state_dict(torch.load(f))
        
    return WrappedTrainer


# Test save and restore
pong_wrapper(ActorCriticTrainer)({"env_name": "Pong-v0"}).save("test")
pong_wrapper(ActorCriticTrainer)({"env_name": "Pong-v0"}).restore("test")
import os
os.remove("checkpoints/pong-agent-test-baseline.pkl")
os.remove("checkpoints/pong-agent-test-policy.pkl")
print("Test passed!")

# %%
# Run this cell without modification

pong_ac_config = dict(
    # environment
    env_name="PongDeterministic-v4",

    # model
    hidden_units=100,

    # training inner loop
    learning_rate=0.0005,

    # training outer loop
    max_iteration=200,
    max_episode_length=5000,  # In fact the game end at 10000 steps
    train_batch_size=5000,

    # evaluation
    evaluate_interval=10,
    evaluate_num_episodes=10
)

ac_trainer_pong, ac_result_pong = run(pong_wrapper(ActorCriticTrainer), pong_ac_config, 18.0)

# Hint: Performance should greater than -20.0 within one hour.
# We do not require you to solve the task, but you need to make your agent achieve > -20 reward.

# %%
surfix = "iter130"

ac_trainer_pong_restored = pong_wrapper(ActorCriticTrainer)(pong_ac_config)
ac_trainer_pong_restored.restore(surfix)

print("Average episode reward for your Actor-critic agent in PongDeterministic-v4: ",
      ac_trainer_pong_restored.evaluate(1, render=True))

# %% [markdown]
# ------
#
# ## Conclusion and Discussion
#
# In this assignment, we implement several policy gradient algorithms.
#
# It's OK to leave the following cells empty. In the next markdown cell, you can write whatever you like. Like the suggestion on the course, the confusing problems in the assignments, and so on.
#
# If you want to do more investigation, feel free to open new cells via `Esc + B` after the next cells and write codes in it, so that you can reuse some result in this notebook. Remember to write sufficient comments and documents to let others know what you are doing.
#
# Following the submission instruction in the assignment to submit your assignment to our staff. Thank you!
#
# ------
